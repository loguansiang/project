# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
# slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
# mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(sand)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-08-14  0.086577  0.086577  0.059597  0.065645   0.065645  118988161
# 2020-08-15  0.066077  0.069509  0.048985  0.050964   0.050964   36213441
# 2020-08-16  0.051438  0.069508  0.048064  0.060847   0.060847   33023213
# 2020-08-17  0.060847  0.065073  0.052525  0.053999   0.053999   11686493
# 2020-08-18  0.053784  0.060990  0.050675  0.051700   0.051700    7401293
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923   2.869923  321784424
# 2022-04-14  2.869366  2.916186  2.714203  2.780882   2.780882  349909147
# 2022-04-15  2.781060  2.820187  2.755915  2.803639   2.803639  189256519
# 2022-04-16  2.803614  2.901280  2.777383  2.822680   2.822680  234480315
# 2022-04-17  2.820111  2.820111  2.781153  2.790278   2.790278  176793328
#
# [612 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=f52cbdbcadbbd4e30e9319d20a34e473ca819c423d7d239020827ffe4828e863
#   Stored in directory: /root/.cache/pip/wheels/1b/81/50/db21d9643326c61dd6fee1dc2562d8351ee7753164c24ead38
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2020-08-20  0.052095  0.057325  0.050800  0.053648    7332475   0.052095
# 2020-08-21  0.053644  0.053738  0.044235  0.044235    5121097   0.053648
# 2020-08-22  0.044395  0.049011  0.040692  0.046011    4347394   0.044235
# 2020-08-23  0.045990  0.048237  0.041965  0.044007    3114426   0.046011
# 2020-08-24  0.043902  0.053543  0.042178  0.051299    7868186   0.044007
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923  321784424   2.782421
# 2022-04-14  2.869366  2.916186  2.714203  2.780882  349909147   2.869923
# 2022-04-15  2.781060  2.820187  2.755915  2.803639  189256519   2.780882
# 2022-04-16  2.803614  2.901280  2.777383  2.822680  234480315   2.803639
# 2022-04-17  2.820111  2.820111  2.781153  2.790278  176793328   2.822680
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2020-08-20  0.006525 -0.001553  0.055557  36.094661  0.054128
# 2020-08-21  0.009503  0.009409  0.052498  23.308807  0.051380
# 2020-08-22  0.008319 -0.001616  0.051791  28.856159  0.049928
# 2020-08-23  0.006272  0.001983  0.049385  26.347291  0.048360
# 2020-08-24  0.011365 -0.007397  0.048999  46.203257  0.049127
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.135098 -0.087940  2.886363  40.236566  2.909637
# 2022-04-14  0.201983  0.088484  2.843185  36.188051  2.877448
# 2022-04-15  0.064272 -0.022579  2.829312  38.046757  2.858996
# 2022-04-16  0.123897 -0.019066  2.803156  39.759602  2.849917
# 2022-04-17  0.038958  0.029833  2.788510  37.690803  2.835007
#
# [606 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['rsi_7','EMA_7']])
Y_data = Y_scaler.fit_transform(df[['Close']])

##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
# x_train

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[0.28354178 0.00301667]
#  [0.13017381 0.00260212]
#  [0.19671502 0.00238325]
#  [0.16662082 0.00214664]
#  [0.40479569 0.00226236]
#  [0.3372283  0.00222159]
#  [0.55600539 0.00257865]
#  [0.73288956 0.00344186]
#  [0.646305   0.00392704]
#  [0.67646739 0.00439727]]
#
#  Target horizon
#
# [[0.0047021 ]
#  [0.00347374]
#  [0.00337472]
#  [0.00161431]
#  [0.00174523]
#  [0.00080584]
#  [0.00120685]
#  [0.00084849]
#  [0.0022731 ]
#  [0.00209141]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 32

train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 2)

# %%
#define model
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras import regularizers

# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.001
l2_rate=regularizers.l2(0.0001)
# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)

# Set random seed for as reproducible results as possible
tf.random.set_seed(7)
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(x_train.shape[-2:]),kernel_regularizer= l2_rate))
cnn_model.add(Conv1D(filters=64, kernel_size=1,kernel_regularizer= l2_rate))
cnn_model.add(MaxPooling1D(pool_size=(1)))
cnn_model.add(Conv1D(filters=128, kernel_size=1,kernel_regularizer= l2_rate))
cnn_model.add(Flatten())
cnn_model.add(Dense(256,kernel_regularizer= l2_rate))
cnn_model.add(Dropout(0.2))
cnn_model.add(Dense(10))
# Compile the model with the optimizer
cnn_model.compile(optimizer=optimizer, loss='mse')
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 32)            96
#
#  conv1d_1 (Conv1D)           (None, 10, 64)            2112
#
#  max_pooling1d (MaxPooling1D  (None, 10, 64)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 10, 128)           8320
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 341,034
# Trainable params: 341,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers

# Set random seed for as reproducible results as possible
# tf.random.set_seed(7)

# lstm_model = Sequential()
# lstm_model.add(LSTM(100,return_sequences=True,input_shape=(x_train.shape[-2:])))
# lstm_model.add(Dense(20,activation='linear'))
# lstm_model.add(LSTM(50))
# lstm_model.add(Dropout(0.2))
# lstm_model.add(Dense(units=horizon,activation='linear'))
# lstm_model.compile(loss='mean_squared_error', optimizer='adam')
# lstm_model.summary()

# %%
history = cnn_model.fit(train_data,epochs=100,batch_size=32,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 2s 12ms/step - loss: 0.0826 - val_loss: 0.0962
# Epoch 2/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0516 - val_loss: 0.0593
# Epoch 3/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0421 - val_loss: 0.0459
# Epoch 4/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0346 - val_loss: 0.0484
# Epoch 5/100
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0298 - val_loss: 0.0501
# Epoch 6/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0281 - val_loss: 0.0365
# Epoch 7/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0229 - val_loss: 0.0348
# Epoch 8/100
# 100/100 [==============================] - 2s 23ms/step - loss: 0.0205 - val_loss: 0.0338
# Epoch 9/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0184 - val_loss: 0.0327
# Epoch 10/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0173 - val_loss: 0.0248
# Epoch 11/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0161 - val_loss: 0.0269
# Epoch 12/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0137 - val_loss: 0.0234
# Epoch 13/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0137 - val_loss: 0.0315
# Epoch 14/100
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0127 - val_loss: 0.0240
# Epoch 15/100
# 100/100 [==============================] - 2s 23ms/step - loss: 0.0143 - val_loss: 0.0288
# Epoch 16/100
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0536 - val_loss: 0.2585
# Epoch 17/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0370 - val_loss: 0.0216
# Epoch 18/100
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0134 - val_loss: 0.0242
# Epoch 19/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0108 - val_loss: 0.0189
# Epoch 20/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0110 - val_loss: 0.0240
# Epoch 21/100
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0105 - val_loss: 0.0294
# Epoch 22/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0100 - val_loss: 0.0167
# Epoch 23/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0094 - val_loss: 0.0229
# Epoch 24/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0094 - val_loss: 0.0293
# Epoch 25/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0082 - val_loss: 0.0170
# Epoch 26/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0091 - val_loss: 0.0227
# Epoch 27/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0084 - val_loss: 0.0262
# Epoch 28/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0078 - val_loss: 0.0170
# Epoch 29/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0079 - val_loss: 0.0225
# Epoch 30/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0076 - val_loss: 0.0271
# Epoch 31/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0070 - val_loss: 0.0141
# Epoch 32/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0073 - val_loss: 0.0238
# Epoch 33/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0071 - val_loss: 0.0288
# Epoch 34/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0066 - val_loss: 0.0137
# Epoch 35/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0068 - val_loss: 0.0241
# Epoch 36/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0065 - val_loss: 0.0269
# Epoch 37/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0058 - val_loss: 0.0148
# Epoch 38/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0068 - val_loss: 0.0287
# Epoch 39/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0106 - val_loss: 0.0210
# Epoch 40/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0141 - val_loss: 0.0347
# Epoch 41/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0096 - val_loss: 0.0188
# Epoch 42/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0057 - val_loss: 0.0185
# Epoch 43/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0232
# Epoch 44/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0212
# Epoch 45/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 0.0201
# Epoch 46/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0287
# Epoch 47/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0213
# Epoch 48/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0130
# Epoch 49/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0307
# Epoch 50/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 0.0205
# Epoch 51/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0155
# Epoch 52/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0046 - val_loss: 0.0314
# Epoch 53/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 54/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0196 - val_loss: 0.0388
# Epoch 55/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0235 - val_loss: 0.0193
# Epoch 56/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0061 - val_loss: 0.0186
# Epoch 57/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0052 - val_loss: 0.0187
# Epoch 58/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0045 - val_loss: 0.0283
# Epoch 59/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0162
# Epoch 60/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0131
# Epoch 61/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0265
# Epoch 62/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0165
# Epoch 63/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0154
# Epoch 64/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0042 - val_loss: 0.0283
# Epoch 65/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0040 - val_loss: 0.0245
# Epoch 66/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0046 - val_loss: 0.0281
# Epoch 67/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0038 - val_loss: 0.0181
# Epoch 68/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0041 - val_loss: 0.0237
# Epoch 69/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0036 - val_loss: 0.0205
# Epoch 70/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0035 - val_loss: 0.0369
# Epoch 71/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0044 - val_loss: 0.0185
# Epoch 72/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0044 - val_loss: 0.0100
# Epoch 73/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0079 - val_loss: 0.1695
# Epoch 74/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0380 - val_loss: 0.0722
# Epoch 75/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0317 - val_loss: 0.0268
# Epoch 76/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0089 - val_loss: 0.0150
# Epoch 77/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0217
# Epoch 78/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0347
# Epoch 79/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0045 - val_loss: 0.0219
# Epoch 80/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0041 - val_loss: 0.0331
# Epoch 81/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0312
# Epoch 82/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 0.0324
# Epoch 83/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0039 - val_loss: 0.0269
# Epoch 84/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0040 - val_loss: 0.0165
# Epoch 85/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0037 - val_loss: 0.0275
# Epoch 86/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0286
# Epoch 87/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0040 - val_loss: 0.0184
# Epoch 88/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0032 - val_loss: 0.0346
# Epoch 89/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0296
# Epoch 90/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0037 - val_loss: 0.0157
# Epoch 91/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0037 - val_loss: 0.0229
# Epoch 92/100
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0034 - val_loss: 0.0294
# Epoch 93/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0034 - val_loss: 0.0189
# Epoch 94/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0034 - val_loss: 0.0373
# Epoch 95/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0035 - val_loss: 0.0279
# Epoch 96/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0032 - val_loss: 0.0286
# Epoch 97/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0033 - val_loss: 0.0139
# Epoch 98/100
# 100/100 [==============================] - 1s 15ms/step - loss: 0.0036 - val_loss: 0.0291
# Epoch 99/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0035 - val_loss: 0.0166
# Epoch 100/100
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0034 - val_loss: 0.0370

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['open']


data_val = X_scaler.fit_transform(df[['rsi_7','EMA_7']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=cnn_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 0s 145ms/step
# array([[2.827212 , 2.642937 , 2.5191746, 2.4890974, 2.459841 , 2.350128 ,
#         2.2779262, 2.270621 , 2.1419158, 2.1912134]], dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.2042921382867128
# MAE is : 0.4148823643341064
# RMSE is : 0.45198687844528496
# MAPE is : 14.667912390419085

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
