# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
#sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
# mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(slp)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-07-08  0.199600  0.200201  0.109705  0.110012   0.110012       8412
# 2020-07-09  0.110270  0.149273  0.062864  0.091263   0.091263       5864
# 2020-07-10  0.091247  0.104638  0.045408  0.055206   0.055206        302
# 2020-07-11  0.055206  0.089824  0.023832  0.033257   0.033257        380
# 2020-07-12  0.033253  0.033525  0.018149  0.018416   0.018416         42
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  0.016956  0.017662  0.016659  0.017561   0.017561  195753852
# 2022-04-14  0.017563  0.018326  0.016753  0.017127   0.017127  214228125
# 2022-04-15  0.017128  0.017279  0.016853  0.017239   0.017239  107932100
# 2022-04-16  0.017242  0.017618  0.016952  0.017152   0.017152  128101400
# 2022-04-17  0.017156  0.017343  0.017092  0.017194   0.017194  110862176
#
# [649 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=e4c12c34214d13b1205a9aafc65796ac13859c258f676b3225855a132ffeaf3d
#   Stored in directory: /root/.cache/pip/wheels/1b/81/50/db21d9643326c61dd6fee1dc2562d8351ee7753164c24ead38
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2020-07-14  0.012000  0.076397  0.011938  0.034327        419   0.011982
# 2020-07-15  0.034318  0.034480  0.010670  0.010735         79   0.034327
# 2020-07-16  0.010729  0.010755  0.009543  0.009627         35   0.010735
# 2020-07-17  0.009628  0.009658  0.009562  0.009590         35   0.009627
# 2020-07-18  0.009594  0.011825  0.009574  0.011774         42   0.009590
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  0.016956  0.017662  0.016659  0.017561  195753852   0.016955
# 2022-04-14  0.017563  0.018326  0.016753  0.017127  214228125   0.017561
# 2022-04-15  0.017128  0.017279  0.016853  0.017239  107932100   0.017127
# 2022-04-16  0.017242  0.017618  0.016952  0.017152  128101400   0.017239
# 2022-04-17  0.017156  0.017343  0.017092  0.017194  110862176   0.017152
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2020-07-14  0.064459 -0.022327  0.050638  27.681177  0.036470
# 2020-07-15  0.023810  0.023583  0.036455  20.642657  0.029320
# 2020-07-16  0.001212  0.001102  0.024793  20.359012  0.023997
# 2020-07-17  0.000096  0.000038  0.018276  20.348119  0.020181
# 2020-07-18  0.002251 -0.002180  0.015207  23.178636  0.017986
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.001003 -0.000605  0.018427  37.914164  0.018445
# 2022-04-14  0.001573  0.000436  0.017850  35.801746  0.018116
# 2022-04-15  0.000426 -0.000111  0.017545  36.860883  0.017897
# 2022-04-16  0.000666  0.000090  0.017231  36.317886  0.017710
# 2022-04-17  0.000251 -0.000038  0.017078  36.841893  0.017581
#
# [643 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['Pre_Close']])
Y_data = Y_scaler.fit_transform(df[['Close']])

##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
x_train
# Out:
# array([[[0.00738709],
#         [0.07036482],
#         [0.00387252],
#         ...,
#         [0.00772249],
#         [0.00895414],
#         [0.01145408]],
#
#        [[0.07036482],
#         [0.00387252],
#         [0.0007497 ],
#         ...,
#         [0.00895414],
#         [0.01145408],
#         [0.01323533]],
#
#        [[0.00387252],
#         [0.0007497 ],
#         [0.00064542],
#         ...,
#         [0.01145408],
#         [0.01323533],
#         [0.01386665]],
#
#        ...,
#
#        [[0.13914568],
#         [0.14034069],
#         [0.14079164],
#         ...,
#         [0.11549345],
#         [0.09061521],
#         [0.08447386]],
#
#        [[0.14034069],
#         [0.14079164],
#         [0.13919923],
#         ...,
#         [0.09061521],
#         [0.08447386],
#         [0.08504036]],
#
#        [[0.14079164],
#         [0.13919923],
#         [0.13744617],
#         ...,
#         [0.08447386],
#         [0.08504036],
#         [0.08621282]]])

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[0.00738709]
#  [0.07036482]
#  [0.00387252]
#  [0.0007497 ]
#  [0.00064542]
#  [0.00680086]
#  [0.00802124]
#  [0.00772249]
#  [0.00895414]
#  [0.01145408]]
#
#  Target horizon
#
# [[0.0345849 ]
#  [0.035732  ]
#  [0.04800906]
#  [0.04678023]
#  [0.01231652]
#  [0.01026189]
#  [0.0107692 ]
#  [0.01726849]
#  [0.02293917]
#  [0.02313082]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 64
buffer_size = 18

train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.optimizers import Adam
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.00001

# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)

lstm_model = Sequential()
lstm_model.add(GRU(64,return_sequences=True,input_shape=(x_train.shape[-2:])))
lstm_model.add(Dense(20,activation='linear'))
lstm_model.add(GRU(32))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(units=horizon,activation='linear'))
lstm_model.add(Activation('linear'))
lstm_model.compile(optimizer=optimizer, loss='mse')
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 10, 64)            12864
#
#  dense (Dense)               (None, 10, 20)            1300
#
#  gru_1 (GRU)                 (None, 32)                5184
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 10)                330
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 19,678
# Trainable params: 19,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = lstm_model.fit(train_data,epochs=100,steps_per_epoch=100,batch_size=64,validation_data=val_data,validation_steps=50,verbose=1)#callback
##history = cnn_model.fit(train_data,epochs=50,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 13s 53ms/step - loss: 0.0773 - val_loss: 7.7941e-04
# Epoch 2/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0797 - val_loss: 5.7509e-04
# Epoch 3/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0707 - val_loss: 4.4351e-04
# Epoch 4/100
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0726 - val_loss: 3.8801e-04
# Epoch 5/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0643 - val_loss: 4.1848e-04
# Epoch 6/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0659 - val_loss: 5.4428e-04
# Epoch 7/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0579 - val_loss: 7.7260e-04
# Epoch 8/100
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0590 - val_loss: 0.0011
# Epoch 9/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0514 - val_loss: 0.0016
# Epoch 10/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0525 - val_loss: 0.0021
# Epoch 11/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0457 - val_loss: 0.0028
# Epoch 12/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0464 - val_loss: 0.0035
# Epoch 13/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0408 - val_loss: 0.0043
# Epoch 14/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0418 - val_loss: 0.0051
# Epoch 15/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0369 - val_loss: 0.0058
# Epoch 16/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0377 - val_loss: 0.0066
# Epoch 17/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0343 - val_loss: 0.0072
# Epoch 18/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0353 - val_loss: 0.0077
# Epoch 19/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0321 - val_loss: 0.0082
# Epoch 20/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0330 - val_loss: 0.0085
# Epoch 21/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0302 - val_loss: 0.0087
# Epoch 22/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0316 - val_loss: 0.0088
# Epoch 23/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0286 - val_loss: 0.0089
# Epoch 24/100
# 100/100 [==============================] - 2s 15ms/step - loss: 0.0306 - val_loss: 0.0089
# Epoch 25/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0280 - val_loss: 0.0087
# Epoch 26/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0290 - val_loss: 0.0086
# Epoch 27/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0267 - val_loss: 0.0084
# Epoch 28/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0280 - val_loss: 0.0082
# Epoch 29/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0263 - val_loss: 0.0080
# Epoch 30/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0273 - val_loss: 0.0077
# Epoch 31/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0251 - val_loss: 0.0074
# Epoch 32/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0265 - val_loss: 0.0071
# Epoch 33/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0245 - val_loss: 0.0068
# Epoch 34/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0256 - val_loss: 0.0065
# Epoch 35/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0238 - val_loss: 0.0062
# Epoch 36/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0249 - val_loss: 0.0060
# Epoch 37/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0231 - val_loss: 0.0057
# Epoch 38/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0242 - val_loss: 0.0054
# Epoch 39/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0227 - val_loss: 0.0051
# Epoch 40/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0239 - val_loss: 0.0049
# Epoch 41/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0223 - val_loss: 0.0046
# Epoch 42/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0234 - val_loss: 0.0044
# Epoch 43/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0218 - val_loss: 0.0041
# Epoch 44/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0233 - val_loss: 0.0039
# Epoch 45/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0213 - val_loss: 0.0037
# Epoch 46/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0227 - val_loss: 0.0035
# Epoch 47/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0209 - val_loss: 0.0034
# Epoch 48/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0224 - val_loss: 0.0032
# Epoch 49/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0204 - val_loss: 0.0031
# Epoch 50/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0223 - val_loss: 0.0029
# Epoch 51/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0206 - val_loss: 0.0028
# Epoch 52/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0220 - val_loss: 0.0027
# Epoch 53/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0204 - val_loss: 0.0026
# Epoch 54/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0216 - val_loss: 0.0025
# Epoch 55/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0199 - val_loss: 0.0024
# Epoch 56/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0215 - val_loss: 0.0024
# Epoch 57/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0199 - val_loss: 0.0023
# Epoch 58/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0214 - val_loss: 0.0022
# Epoch 59/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0197 - val_loss: 0.0021
# Epoch 60/100
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0213 - val_loss: 0.0021
# Epoch 61/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0197 - val_loss: 0.0020
# Epoch 62/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0209 - val_loss: 0.0020
# Epoch 63/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0192 - val_loss: 0.0019
# Epoch 64/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0206 - val_loss: 0.0019
# Epoch 65/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0193 - val_loss: 0.0019
# Epoch 66/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0207 - val_loss: 0.0019
# Epoch 67/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0193 - val_loss: 0.0018
# Epoch 68/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0205 - val_loss: 0.0018
# Epoch 69/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0191 - val_loss: 0.0018
# Epoch 70/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0204 - val_loss: 0.0018
# Epoch 71/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0190 - val_loss: 0.0017
# Epoch 72/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0200 - val_loss: 0.0017
# Epoch 73/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0191 - val_loss: 0.0017
# Epoch 74/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0202 - val_loss: 0.0017
# Epoch 75/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0187 - val_loss: 0.0017
# Epoch 76/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0197 - val_loss: 0.0017
# Epoch 77/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0187 - val_loss: 0.0017
# Epoch 78/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0200 - val_loss: 0.0017
# Epoch 79/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0186 - val_loss: 0.0016
# Epoch 80/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0198 - val_loss: 0.0016
# Epoch 81/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0184 - val_loss: 0.0016
# Epoch 82/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0200 - val_loss: 0.0016
# Epoch 83/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0184 - val_loss: 0.0016
# Epoch 84/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0198 - val_loss: 0.0016
# Epoch 85/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0181 - val_loss: 0.0016
# Epoch 86/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0195 - val_loss: 0.0016
# Epoch 87/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0181 - val_loss: 0.0016
# Epoch 88/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0196 - val_loss: 0.0016
# Epoch 89/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0183 - val_loss: 0.0016
# Epoch 90/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0195 - val_loss: 0.0016
# Epoch 91/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0184 - val_loss: 0.0015
# Epoch 92/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0192 - val_loss: 0.0015
# Epoch 93/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0181 - val_loss: 0.0015
# Epoch 94/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0193 - val_loss: 0.0015
# Epoch 95/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0178 - val_loss: 0.0015
# Epoch 96/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0192 - val_loss: 0.0015
# Epoch 97/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0177 - val_loss: 0.0015
# Epoch 98/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0190 - val_loss: 0.0015
# Epoch 99/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0178 - val_loss: 0.0015
# Epoch 100/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0190 - val_loss: 0.0015

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']].tail(10))
data_val = X_scaler.fit_transform(df[['Pre_Close']].tail(10))
# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=lstm_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 1s 744ms/step
# array([[0.08455645, 0.08479199, 0.08106637, 0.08256573, 0.08276767,
#         0.08096239, 0.0790324 , 0.07623077, 0.08530085, 0.08167673]],
#       dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.004133018483564042
# MAE is : 0.06424193534307479
# RMSE is : 0.06428855639664062
# MAPE is : 364.9713774688372

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
