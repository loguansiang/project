# %% [markdown]
# **(SAND) GRU model -‘Open’, ‘EMA_7’**

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
# slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
# mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(sand)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-08-14  0.086577  0.086577  0.059597  0.065645   0.065645  118988161
# 2020-08-15  0.066077  0.069509  0.048985  0.050964   0.050964   36213441
# 2020-08-16  0.051438  0.069508  0.048064  0.060847   0.060847   33023213
# 2020-08-17  0.060847  0.065073  0.052525  0.053999   0.053999   11686493
# 2020-08-18  0.053784  0.060990  0.050675  0.051700   0.051700    7401293
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923   2.869923  321784424
# 2022-04-14  2.869366  2.916186  2.714203  2.780882   2.780882  349909147
# 2022-04-15  2.781060  2.820187  2.755915  2.803639   2.803639  189256519
# 2022-04-16  2.803614  2.901280  2.777383  2.822680   2.822680  234480315
# 2022-04-17  2.820111  2.820111  2.781153  2.790278   2.790278  176793328
#
# [612 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=c861fe7d801923e4145e34d42916dd45ec929d74d493c43df355ddbe4da7f83a
#   Stored in directory: /root/.cache/pip/wheels/1b/81/50/db21d9643326c61dd6fee1dc2562d8351ee7753164c24ead38
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2020-08-20  0.052095  0.057325  0.050800  0.053648    7332475   0.052095
# 2020-08-21  0.053644  0.053738  0.044235  0.044235    5121097   0.053648
# 2020-08-22  0.044395  0.049011  0.040692  0.046011    4347394   0.044235
# 2020-08-23  0.045990  0.048237  0.041965  0.044007    3114426   0.046011
# 2020-08-24  0.043902  0.053543  0.042178  0.051299    7868186   0.044007
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923  321784424   2.782421
# 2022-04-14  2.869366  2.916186  2.714203  2.780882  349909147   2.869923
# 2022-04-15  2.781060  2.820187  2.755915  2.803639  189256519   2.780882
# 2022-04-16  2.803614  2.901280  2.777383  2.822680  234480315   2.803639
# 2022-04-17  2.820111  2.820111  2.781153  2.790278  176793328   2.822680
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2020-08-20  0.006525 -0.001553  0.055557  36.094661  0.054128
# 2020-08-21  0.009503  0.009409  0.052498  23.308807  0.051380
# 2020-08-22  0.008319 -0.001616  0.051791  28.856159  0.049928
# 2020-08-23  0.006272  0.001983  0.049385  26.347291  0.048360
# 2020-08-24  0.011365 -0.007397  0.048999  46.203257  0.049127
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.135098 -0.087940  2.886363  40.236566  2.909637
# 2022-04-14  0.201983  0.088484  2.843185  36.188051  2.877448
# 2022-04-15  0.064272 -0.022579  2.829312  38.046757  2.858996
# 2022-04-16  0.123897 -0.019066  2.803156  39.759602  2.849917
# 2022-04-17  0.038958  0.029833  2.788510  37.690803  2.835007
#
# [606 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['H-L',	'0-C','SMA_7','rsi_7','EMA_7']])
Y_data = Y_scaler.fit_transform(df[['Close']])

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[0.00191371 0.63511549 0.00303412 0.28354178 0.00301667]
#  [0.00300256 0.64105838 0.00260118 0.13017381 0.00260212]
#  [0.00256966 0.63508134 0.00250103 0.19671502 0.00238325]
#  [0.00182121 0.63703248 0.0021605  0.16662082 0.00214664]
#  [0.00368337 0.63194726 0.0021059  0.40479569 0.00226236]
#  [0.00357807 0.63748354 0.0020327  0.3372283  0.00222159]
#  [0.00379452 0.63052469 0.00215415 0.55600539 0.00257865]
#  [0.00706034 0.62761614 0.00255979 0.73288956 0.00344186]
#  [0.00431189 0.63843715 0.00307355 0.646305   0.00392704]
#  [0.00264717 0.6344118  0.00360937 0.67646739 0.00439727]]
#
#  Target horizon
#
# [[0.0047021 ]
#  [0.00347374]
#  [0.00337472]
#  [0.00161431]
#  [0.00174523]
#  [0.00080584]
#  [0.00120685]
#  [0.00084849]
#  [0.0022731 ]
#  [0.00209141]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 16


train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 5)

# %%
#define model
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras import regularizers
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.0005

# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
l1_rate=regularizers.l1(0.01)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=16, kernel_size=1, activation='relu', input_shape=(x_train.shape[-2:]),activity_regularizer= l1_rate))
cnn_model.add(Conv1D(filters=32, kernel_size=1,activity_regularizer= l1_rate))
cnn_model.add(MaxPooling1D(pool_size=(1)))
cnn_model.add(Conv1D(filters=64, kernel_size=1,activity_regularizer= l1_rate))
cnn_model.add(Flatten())
cnn_model.add(Dense(128,activity_regularizer= l1_rate))
cnn_model.add(Dropout(0.2))
cnn_model.add(Dense(10,activity_regularizer= l1_rate))
# Compile the model with the optimizer
cnn_model.compile(optimizer=optimizer, loss='mse')
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 16)            96
#
#  conv1d_1 (Conv1D)           (None, 10, 32)            544
#
#  max_pooling1d (MaxPooling1D  (None, 10, 32)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 10, 64)            2112
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 128)               82048
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 86,090
# Trainable params: 86,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = cnn_model.fit(train_data,epochs=100,batch_size=16,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 2s 7ms/step - loss: 0.7913 - val_loss: 0.9675
# Epoch 2/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3854 - val_loss: 0.7511
# Epoch 3/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2831 - val_loss: 0.6271
# Epoch 4/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2105 - val_loss: 0.5374
# Epoch 5/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1757 - val_loss: 0.4539
# Epoch 6/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1606 - val_loss: 0.3943
# Epoch 7/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1314 - val_loss: 0.3609
# Epoch 8/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1181 - val_loss: 0.3050
# Epoch 9/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.1135 - val_loss: 0.2711
# Epoch 10/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0947 - val_loss: 0.2470
# Epoch 11/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0853 - val_loss: 0.2206
# Epoch 12/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0833 - val_loss: 0.1941
# Epoch 13/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0708 - val_loss: 0.1777
# Epoch 14/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0657 - val_loss: 0.1712
# Epoch 15/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0669 - val_loss: 0.1533
# Epoch 16/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0565 - val_loss: 0.1451
# Epoch 17/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0547 - val_loss: 0.1563
# Epoch 18/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0569 - val_loss: 0.1334
# Epoch 19/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0475 - val_loss: 0.1268
# Epoch 20/100
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0445 - val_loss: 0.1476
# Epoch 21/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0465 - val_loss: 0.1251
# Epoch 22/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0369 - val_loss: 0.1148
# Epoch 23/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0351 - val_loss: 0.1416
# Epoch 24/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0390 - val_loss: 0.1113
# Epoch 25/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0321 - val_loss: 0.1383
# Epoch 26/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0293 - val_loss: 0.1270
# Epoch 27/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0343 - val_loss: 0.1083
# Epoch 28/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0280 - val_loss: 0.1358
# Epoch 29/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0271 - val_loss: 0.1191
# Epoch 30/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0320 - val_loss: 0.1108
# Epoch 31/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0257 - val_loss: 0.1314
# Epoch 32/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0255 - val_loss: 0.1157
# Epoch 33/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0303 - val_loss: 0.1065
# Epoch 34/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0252 - val_loss: 0.1295
# Epoch 35/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0246 - val_loss: 0.1216
# Epoch 36/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0297 - val_loss: 0.1064
# Epoch 37/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0242 - val_loss: 0.1273
# Epoch 38/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0242 - val_loss: 0.1189
# Epoch 39/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0287 - val_loss: 0.1061
# Epoch 40/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0234 - val_loss: 0.1253
# Epoch 41/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0230 - val_loss: 0.1144
# Epoch 42/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0278 - val_loss: 0.1041
# Epoch 43/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0229 - val_loss: 0.1221
# Epoch 44/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0228 - val_loss: 0.1164
# Epoch 45/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0277 - val_loss: 0.1019
# Epoch 46/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0230 - val_loss: 0.1226
# Epoch 47/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0224 - val_loss: 0.1117
# Epoch 48/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0285 - val_loss: 0.1017
# Epoch 49/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0246 - val_loss: 0.1178
# Epoch 50/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.1225
# Epoch 51/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0298 - val_loss: 0.0986
# Epoch 52/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0224 - val_loss: 0.1138
# Epoch 53/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0217 - val_loss: 0.1087
# Epoch 54/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0265 - val_loss: 0.0964
# Epoch 55/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0219 - val_loss: 0.1144
# Epoch 56/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0217 - val_loss: 0.1050
# Epoch 57/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0261 - val_loss: 0.0952
# Epoch 58/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0219 - val_loss: 0.1134
# Epoch 59/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0216 - val_loss: 0.1047
# Epoch 60/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0266 - val_loss: 0.0949
# Epoch 61/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0234 - val_loss: 0.1138
# Epoch 62/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0220 - val_loss: 0.1071
# Epoch 63/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0263 - val_loss: 0.0944
# Epoch 64/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0229 - val_loss: 0.1179
# Epoch 65/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0224 - val_loss: 0.1116
# Epoch 66/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0271 - val_loss: 0.0943
# Epoch 67/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0224 - val_loss: 0.1124
# Epoch 68/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0214 - val_loss: 0.1058
# Epoch 69/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0261 - val_loss: 0.0930
# Epoch 70/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0223 - val_loss: 0.1109
# Epoch 71/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0220 - val_loss: 0.1105
# Epoch 72/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0278 - val_loss: 0.0927
# Epoch 73/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0236 - val_loss: 0.1111
# Epoch 74/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0229 - val_loss: 0.1074
# Epoch 75/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0254 - val_loss: 0.0923
# Epoch 76/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0210 - val_loss: 0.1092
# Epoch 77/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0212 - val_loss: 0.1025
# Epoch 78/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0251 - val_loss: 0.0919
# Epoch 79/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0217 - val_loss: 0.1079
# Epoch 80/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0212 - val_loss: 0.1055
# Epoch 81/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0255 - val_loss: 0.0912
# Epoch 82/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0223 - val_loss: 0.1057
# Epoch 83/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0223 - val_loss: 0.1015
# Epoch 84/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0256 - val_loss: 0.0906
# Epoch 85/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0218 - val_loss: 0.1109
# Epoch 86/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0210 - val_loss: 0.1018
# Epoch 87/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0253 - val_loss: 0.0922
# Epoch 88/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0232 - val_loss: 0.1128
# Epoch 89/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0234 - val_loss: 0.1097
# Epoch 90/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0260 - val_loss: 0.0923
# Epoch 91/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0205 - val_loss: 0.1033
# Epoch 92/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0210 - val_loss: 0.1002
# Epoch 93/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0252 - val_loss: 0.0896
# Epoch 94/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0216 - val_loss: 0.1004
# Epoch 95/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0197 - val_loss: 0.0984
# Epoch 96/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0236 - val_loss: 0.0912
# Epoch 97/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0204 - val_loss: 0.1039
# Epoch 98/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0204 - val_loss: 0.1067
# Epoch 99/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0247 - val_loss: 0.0937
# Epoch 100/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0227 - val_loss: 0.1117

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['open']


data_val = X_scaler.fit_transform(df[['H-L','0-C','SMA_7','rsi_7','EMA_7']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=cnn_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 0s 199ms/step
# array([[3.1440606, 3.2168827, 3.0632737, 3.333583 , 2.9530523, 2.8880038,
#         2.8473642, 2.8653464, 2.9211168, 3.2065215]], dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.0794124245568176
# MAE is : 0.21203151696777348
# RMSE is : 0.28180210176082365
# MAPE is : 7.592872210780369

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
