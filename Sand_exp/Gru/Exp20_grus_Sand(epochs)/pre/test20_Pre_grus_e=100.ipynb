# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
# slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
# mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(sand)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-08-14  0.086577  0.086577  0.059597  0.065645   0.065645  118988161
# 2020-08-15  0.066077  0.069509  0.048985  0.050964   0.050964   36213441
# 2020-08-16  0.051438  0.069508  0.048064  0.060847   0.060847   33023213
# 2020-08-17  0.060847  0.065073  0.052525  0.053999   0.053999   11686493
# 2020-08-18  0.053784  0.060990  0.050675  0.051700   0.051700    7401293
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923   2.869923  321784424
# 2022-04-14  2.869366  2.916186  2.714203  2.780882   2.780882  349909147
# 2022-04-15  2.781060  2.820187  2.755915  2.803639   2.803639  189256519
# 2022-04-16  2.803614  2.901280  2.777383  2.822680   2.822680  234480315
# 2022-04-17  2.820111  2.820111  2.781153  2.790278   2.790278  176793328
#
# [612 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=b70c3f2326cf735c42c413eb6fddec63e03b4599986bc1aaa9ad77c20620df8d
#   Stored in directory: /root/.cache/pip/wheels/1b/81/50/db21d9643326c61dd6fee1dc2562d8351ee7753164c24ead38
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2020-08-20  0.052095  0.057325  0.050800  0.053648    7332475   0.052095
# 2020-08-21  0.053644  0.053738  0.044235  0.044235    5121097   0.053648
# 2020-08-22  0.044395  0.049011  0.040692  0.046011    4347394   0.044235
# 2020-08-23  0.045990  0.048237  0.041965  0.044007    3114426   0.046011
# 2020-08-24  0.043902  0.053543  0.042178  0.051299    7868186   0.044007
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923  321784424   2.782421
# 2022-04-14  2.869366  2.916186  2.714203  2.780882  349909147   2.869923
# 2022-04-15  2.781060  2.820187  2.755915  2.803639  189256519   2.780882
# 2022-04-16  2.803614  2.901280  2.777383  2.822680  234480315   2.803639
# 2022-04-17  2.820111  2.820111  2.781153  2.790278  176793328   2.822680
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2020-08-20  0.006525 -0.001553  0.055557  36.094661  0.054128
# 2020-08-21  0.009503  0.009409  0.052498  23.308807  0.051380
# 2020-08-22  0.008319 -0.001616  0.051791  28.856159  0.049928
# 2020-08-23  0.006272  0.001983  0.049385  26.347291  0.048360
# 2020-08-24  0.011365 -0.007397  0.048999  46.203257  0.049127
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.135098 -0.087940  2.886363  40.236566  2.909637
# 2022-04-14  0.201983  0.088484  2.843185  36.188051  2.877448
# 2022-04-15  0.064272 -0.022579  2.829312  38.046757  2.858996
# 2022-04-16  0.123897 -0.019066  2.803156  39.759602  2.849917
# 2022-04-17  0.038958  0.029833  2.788510  37.690803  2.835007
#
# [606 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['Pre_Close']])
Y_data = Y_scaler.fit_transform(df[['Close']])

##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
x_train
# Out:
# array([[[0.00254128],
#         [0.00272679],
#         [0.00160237],
#         ...,
#         [0.00325873],
#         [0.00512306],
#         [0.00463735]],
#
#        [[0.00272679],
#         [0.00160237],
#         [0.00181452],
#         ...,
#         [0.00512306],
#         [0.00463735],
#         [0.00497983]],
#
#        [[0.00160237],
#         [0.00181452],
#         [0.00157513],
#         ...,
#         [0.00463735],
#         [0.00497983],
#         [0.00427899]],
#
#        ...,
#
#        [[0.71719082],
#         [0.72048789],
#         [0.64484734],
#         ...,
#         [0.57684341],
#         [0.60108472],
#         [0.65043663]],
#
#        [[0.72048789],
#         [0.64484734],
#         [0.65440611],
#         ...,
#         [0.60108472],
#         [0.65043663],
#         [0.56925504]],
#
#        [[0.64484734],
#         [0.65440611],
#         [0.63282672],
#         ...,
#         [0.65043663],
#         [0.56925504],
#         [0.56713209]]])

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[0.00254128]
#  [0.00272679]
#  [0.00160237]
#  [0.00181452]
#  [0.00157513]
#  [0.00244619]
#  [0.00206167]
#  [0.00325873]
#  [0.00512306]
#  [0.00463735]]
#
#  Target horizon
#
# [[0.0047021 ]
#  [0.00347374]
#  [0.00337472]
#  [0.00161431]
#  [0.00174523]
#  [0.00080584]
#  [0.00120685]
#  [0.00084849]
#  [0.0022731 ]
#  [0.00209141]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 64
buffer_size = 18

train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.optimizers import Adam
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.00001

# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)

lstm_model = Sequential()
lstm_model.add(GRU(64,return_sequences=True,input_shape=(x_train.shape[-2:])))
lstm_model.add(Dense(20,activation='linear'))
lstm_model.add(GRU(32))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(units=horizon,activation='linear'))
lstm_model.add(Activation('linear'))
lstm_model.compile(optimizer=optimizer, loss='mse')
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 10, 64)            12864
#
#  dense (Dense)               (None, 10, 20)            1300
#
#  gru_1 (GRU)                 (None, 32)                5184
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 10)                330
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 19,678
# Trainable params: 19,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = lstm_model.fit(train_data,epochs=100,steps_per_epoch=100,batch_size=64,validation_data=val_data,validation_steps=50,verbose=1)#callback
##history = cnn_model.fit(train_data,epochs=50,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 10s 52ms/step - loss: 0.0369 - val_loss: 0.1891
# Epoch 2/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0391 - val_loss: 0.1832
# Epoch 3/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0350 - val_loss: 0.1776
# Epoch 4/100
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0370 - val_loss: 0.1719
# Epoch 5/100
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0331 - val_loss: 0.1662
# Epoch 6/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0351 - val_loss: 0.1604
# Epoch 7/100
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0314 - val_loss: 0.1546
# Epoch 8/100
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0331 - val_loss: 0.1486
# Epoch 9/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0297 - val_loss: 0.1427
# Epoch 10/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0315 - val_loss: 0.1368
# Epoch 11/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0282 - val_loss: 0.1308
# Epoch 12/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0297 - val_loss: 0.1249
# Epoch 13/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0268 - val_loss: 0.1190
# Epoch 14/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0281 - val_loss: 0.1132
# Epoch 15/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0254 - val_loss: 0.1074
# Epoch 16/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0267 - val_loss: 0.1018
# Epoch 17/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0242 - val_loss: 0.0962
# Epoch 18/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0254 - val_loss: 0.0908
# Epoch 19/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0232 - val_loss: 0.0855
# Epoch 20/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0244 - val_loss: 0.0804
# Epoch 21/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0223 - val_loss: 0.0755
# Epoch 22/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0232 - val_loss: 0.0707
# Epoch 23/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0211 - val_loss: 0.0662
# Epoch 24/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0222 - val_loss: 0.0619
# Epoch 25/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0202 - val_loss: 0.0577
# Epoch 26/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0213 - val_loss: 0.0539
# Epoch 27/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0193 - val_loss: 0.0502
# Epoch 28/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0201 - val_loss: 0.0467
# Epoch 29/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0185 - val_loss: 0.0433
# Epoch 30/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0187 - val_loss: 0.0402
# Epoch 31/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0174 - val_loss: 0.0372
# Epoch 32/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0182 - val_loss: 0.0344
# Epoch 33/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0167 - val_loss: 0.0318
# Epoch 34/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0169 - val_loss: 0.0294
# Epoch 35/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0158 - val_loss: 0.0272
# Epoch 36/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0162 - val_loss: 0.0251
# Epoch 37/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0146 - val_loss: 0.0232
# Epoch 38/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0148 - val_loss: 0.0214
# Epoch 39/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0138 - val_loss: 0.0198
# Epoch 40/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0144 - val_loss: 0.0184
# Epoch 41/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0130 - val_loss: 0.0171
# Epoch 42/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0135 - val_loss: 0.0159
# Epoch 43/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0124 - val_loss: 0.0149
# Epoch 44/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 45/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0117 - val_loss: 0.0132
# Epoch 46/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0124 - val_loss: 0.0125
# Epoch 47/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0110 - val_loss: 0.0118
# Epoch 48/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0117 - val_loss: 0.0113
# Epoch 49/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 50/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0113 - val_loss: 0.0103
# Epoch 51/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 52/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0109 - val_loss: 0.0096
# Epoch 53/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0102 - val_loss: 0.0093
# Epoch 54/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0105 - val_loss: 0.0090
# Epoch 55/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0095 - val_loss: 0.0087
# Epoch 56/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0104 - val_loss: 0.0085
# Epoch 57/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0095 - val_loss: 0.0083
# Epoch 58/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0101 - val_loss: 0.0081
# Epoch 59/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0095 - val_loss: 0.0079
# Epoch 60/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0103 - val_loss: 0.0078
# Epoch 61/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0093 - val_loss: 0.0077
# Epoch 62/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0099 - val_loss: 0.0076
# Epoch 63/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0090 - val_loss: 0.0074
# Epoch 64/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0097 - val_loss: 0.0074
# Epoch 65/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 66/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0096 - val_loss: 0.0072
# Epoch 67/100
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0090 - val_loss: 0.0071
# Epoch 68/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0094 - val_loss: 0.0071
# Epoch 69/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0088 - val_loss: 0.0070
# Epoch 70/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0093 - val_loss: 0.0070
# Epoch 71/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0085 - val_loss: 0.0069
# Epoch 72/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0091 - val_loss: 0.0069
# Epoch 73/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0084 - val_loss: 0.0068
# Epoch 74/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0091 - val_loss: 0.0068
# Epoch 75/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0085 - val_loss: 0.0067
# Epoch 76/100
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0090 - val_loss: 0.0068
# Epoch 77/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0081 - val_loss: 0.0067
# Epoch 78/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0088 - val_loss: 0.0067
# Epoch 79/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0080 - val_loss: 0.0065
# Epoch 80/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0087 - val_loss: 0.0066
# Epoch 81/100
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0079 - val_loss: 0.0066
# Epoch 82/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0088 - val_loss: 0.0065
# Epoch 83/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0080 - val_loss: 0.0065
# Epoch 84/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0088 - val_loss: 0.0065
# Epoch 85/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0077 - val_loss: 0.0065
# Epoch 86/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0086 - val_loss: 0.0065
# Epoch 87/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0079 - val_loss: 0.0064
# Epoch 88/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0085 - val_loss: 0.0064
# Epoch 89/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0079 - val_loss: 0.0063
# Epoch 90/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0086 - val_loss: 0.0065
# Epoch 91/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 92/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0083 - val_loss: 0.0064
# Epoch 93/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0078 - val_loss: 0.0065
# Epoch 94/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0082 - val_loss: 0.0065
# Epoch 95/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0076 - val_loss: 0.0063
# Epoch 96/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0080 - val_loss: 0.0063
# Epoch 97/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0073 - val_loss: 0.0063
# Epoch 98/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0083 - val_loss: 0.0063
# Epoch 99/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 100/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0079 - val_loss: 0.0064

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']].tail(10))
data_val = X_scaler.fit_transform(df[['Pre_Close']].tail(10))
# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=lstm_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 1s 784ms/step
# array([[2.947981 , 3.088181 , 3.0321338, 3.0296233, 2.8942046, 2.84901  ,
#         2.820842 , 2.8382118, 3.0557883, 3.0376973]], dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.02892273847168359
# MAE is : 0.13166092478332522
# RMSE is : 0.17006686470821877
# MAPE is : 4.7208235275288795

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
