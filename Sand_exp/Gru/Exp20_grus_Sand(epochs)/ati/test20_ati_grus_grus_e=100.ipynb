# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
# slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
# mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(sand)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-08-14  0.086577  0.086577  0.059597  0.065645   0.065645  118988161
# 2020-08-15  0.066077  0.069509  0.048985  0.050964   0.050964   36213441
# 2020-08-16  0.051438  0.069508  0.048064  0.060847   0.060847   33023213
# 2020-08-17  0.060847  0.065073  0.052525  0.053999   0.053999   11686493
# 2020-08-18  0.053784  0.060990  0.050675  0.051700   0.051700    7401293
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923   2.869923  321784424
# 2022-04-14  2.869366  2.916186  2.714203  2.780882   2.780882  349909147
# 2022-04-15  2.781060  2.820187  2.755915  2.803639   2.803639  189256519
# 2022-04-16  2.803614  2.901280  2.777383  2.822680   2.822680  234480315
# 2022-04-17  2.820111  2.820111  2.781153  2.790278   2.790278  176793328
#
# [612 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=5a534ae97cc25e4c158ec54bc62e0886928c48e656d1e2b1d1400d025e1cede1
#   Stored in directory: /root/.cache/pip/wheels/1b/81/50/db21d9643326c61dd6fee1dc2562d8351ee7753164c24ead38
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2020-08-20  0.052095  0.057325  0.050800  0.053648    7332475   0.052095
# 2020-08-21  0.053644  0.053738  0.044235  0.044235    5121097   0.053648
# 2020-08-22  0.044395  0.049011  0.040692  0.046011    4347394   0.044235
# 2020-08-23  0.045990  0.048237  0.041965  0.044007    3114426   0.046011
# 2020-08-24  0.043902  0.053543  0.042178  0.051299    7868186   0.044007
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.781983  2.886945  2.751847  2.869923  321784424   2.782421
# 2022-04-14  2.869366  2.916186  2.714203  2.780882  349909147   2.869923
# 2022-04-15  2.781060  2.820187  2.755915  2.803639  189256519   2.780882
# 2022-04-16  2.803614  2.901280  2.777383  2.822680  234480315   2.803639
# 2022-04-17  2.820111  2.820111  2.781153  2.790278  176793328   2.822680
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2020-08-20  0.006525 -0.001553  0.055557  36.094661  0.054128
# 2020-08-21  0.009503  0.009409  0.052498  23.308807  0.051380
# 2020-08-22  0.008319 -0.001616  0.051791  28.856159  0.049928
# 2020-08-23  0.006272  0.001983  0.049385  26.347291  0.048360
# 2020-08-24  0.011365 -0.007397  0.048999  46.203257  0.049127
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.135098 -0.087940  2.886363  40.236566  2.909637
# 2022-04-14  0.201983  0.088484  2.843185  36.188051  2.877448
# 2022-04-15  0.064272 -0.022579  2.829312  38.046757  2.858996
# 2022-04-16  0.123897 -0.019066  2.803156  39.759602  2.849917
# 2022-04-17  0.038958  0.029833  2.788510  37.690803  2.835007
#
# [606 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['H-L',	'0-C','SMA_7','rsi_7','EMA_7']])
Y_data = Y_scaler.fit_transform(df[['Close']])

##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
x_train
# Out:
# array([[[0.00191371, 0.63511549, 0.00303412, 0.28354178, 0.00301667],
#         [0.00300256, 0.64105838, 0.00260118, 0.13017381, 0.00260212],
#         [0.00256966, 0.63508134, 0.00250103, 0.19671502, 0.00238325],
#         ...,
#         [0.00706034, 0.62761614, 0.00255979, 0.73288956, 0.00344186],
#         [0.00431189, 0.63843715, 0.00307355, 0.646305  , 0.00392704],
#         [0.00264717, 0.6344118 , 0.00360937, 0.67646739, 0.00439727]],
#
#        [[0.00300256, 0.64105838, 0.00260118, 0.13017381, 0.00260212],
#         [0.00256966, 0.63508134, 0.00250103, 0.19671502, 0.00238325],
#         [0.00182121, 0.63703248, 0.0021605 , 0.16662082, 0.00214664],
#         ...,
#         [0.00431189, 0.63843715, 0.00307355, 0.646305  , 0.00392704],
#         [0.00264717, 0.6344118 , 0.00360937, 0.67646739, 0.00439727],
#         [0.00289287, 0.63934089, 0.00406708, 0.55147151, 0.00452496]],
#
#        [[0.00256966, 0.63508134, 0.00250103, 0.19671502, 0.00238325],
#         [0.00182121, 0.63703248, 0.0021605 , 0.16662082, 0.00214664],
#         [0.00368337, 0.63194726, 0.0021059 , 0.40479569, 0.00226236],
#         ...,
#         [0.00264717, 0.6344118 , 0.00360937, 0.67646739, 0.00439727],
#         [0.00289287, 0.63934089, 0.00406708, 0.55147151, 0.00452496],
#         [0.00362706, 0.63418411, 0.00444896, 0.5995042 , 0.00475462]],
#
#        ...,
#
#        [[0.73397694, 0.62532779, 0.93792234, 0.43718621, 0.95914656],
#         [0.33759574, 0.99152155, 0.89623478, 0.32921704, 0.92279183],
#         [0.33521146, 0.5869777 , 0.86664834, 0.34826208, 0.89854316],
#         ...,
#         [0.13939143, 0.527184  , 0.73847802, 0.30244771, 0.79702118],
#         [0.17035491, 0.40928374, 0.73942418, 0.44074887, 0.80296214],
#         [0.33494235, 1.        , 0.72500983, 0.28612906, 0.78179157]],
#
#        [[0.33759574, 0.99152155, 0.89623478, 0.32921704, 0.92279183],
#         [0.33521146, 0.5869777 , 0.86664834, 0.34826208, 0.89854316],
#         [0.1767721 , 0.73569943, 0.83744761, 0.31588481, 0.87354477],
#         ...,
#         [0.17035491, 0.40928374, 0.73942418, 0.44074887, 0.80296214],
#         [0.33494235, 1.        , 0.72500983, 0.28612906, 0.78179157],
#         [0.1215106 , 0.64643907, 0.71388907, 0.28267526, 0.7652435 ]],
#
#        [[0.33521146, 0.5869777 , 0.86664834, 0.34826208, 0.89854316],
#         [0.1767721 , 0.73569943, 0.83744761, 0.31588481, 0.87354477],
#         [0.1617443 , 0.61867579, 0.81268044, 0.32347032, 0.85573291],
#         ...,
#         [0.33494235, 1.        , 0.72500983, 0.28612906, 0.78179157],
#         [0.1215106 , 0.64643907, 0.71388907, 0.28267526, 0.7652435 ],
#         [0.27558066, 0.43984389, 0.70970828, 0.40606606, 0.76671078]]])

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[0.00191371 0.63511549 0.00303412 0.28354178 0.00301667]
#  [0.00300256 0.64105838 0.00260118 0.13017381 0.00260212]
#  [0.00256966 0.63508134 0.00250103 0.19671502 0.00238325]
#  [0.00182121 0.63703248 0.0021605  0.16662082 0.00214664]
#  [0.00368337 0.63194726 0.0021059  0.40479569 0.00226236]
#  [0.00357807 0.63748354 0.0020327  0.3372283  0.00222159]
#  [0.00379452 0.63052469 0.00215415 0.55600539 0.00257865]
#  [0.00706034 0.62761614 0.00255979 0.73288956 0.00344186]
#  [0.00431189 0.63843715 0.00307355 0.646305   0.00392704]
#  [0.00264717 0.6344118  0.00360937 0.67646739 0.00439727]]
#
#  Target horizon
#
# [[0.0047021 ]
#  [0.00347374]
#  [0.00337472]
#  [0.00161431]
#  [0.00174523]
#  [0.00080584]
#  [0.00120685]
#  [0.00084849]
#  [0.0022731 ]
#  [0.00209141]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 16

train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 5)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.optimizers import Adam
from tensorflow.python.keras import regularizers
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.00001

l1_rate=regularizers.l1(0.001)
l2_rate=regularizers.l2(0.0001)
# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)

lstm_model = Sequential()
lstm_model.add(GRU(100,return_sequences=True,input_shape=(x_train.shape[-2:]),activity_regularizer= l1_rate,kernel_regularizer= l2_rate))
lstm_model.add(Dense(20,activation='linear',activity_regularizer= l1_rate,kernel_regularizer= l2_rate))
lstm_model.add(GRU(50,kernel_regularizer= l2_rate))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(units=horizon,activation='linear',kernel_regularizer= l2_rate))
lstm_model.add(Activation('linear'))
lstm_model.compile(optimizer=optimizer, loss='mse')
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 10, 100)           32100
#
#  dense (Dense)               (None, 10, 20)            2020
#
#  gru_1 (GRU)                 (None, 50)                10800
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 10)                510
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 45,430
# Trainable params: 45,430
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model_path = 'CNN_Multivariate.h5'
#early_stopings = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='min')
#checkpoint =  tf.keras.callbacks.ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, mode='min', verbose=0)
#callbacks=[early_stopings,checkpoint]

# %%
history = lstm_model.fit(train_data,epochs=100,batch_size=16,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)#callback
##history = cnn_model.fit(train_data,epochs=50,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 8s 31ms/step - loss: 0.1142 - val_loss: 0.2768
# Epoch 2/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.1087 - val_loss: 0.2665
# Epoch 3/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1144 - val_loss: 0.2574
# Epoch 4/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0991 - val_loss: 0.2490
# Epoch 5/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0960 - val_loss: 0.2422
# Epoch 6/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1027 - val_loss: 0.2356
# Epoch 7/100
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0892 - val_loss: 0.2286
# Epoch 8/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0868 - val_loss: 0.2227
# Epoch 9/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0934 - val_loss: 0.2167
# Epoch 10/100
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0812 - val_loss: 0.2105
# Epoch 11/100
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0790 - val_loss: 0.2051
# Epoch 12/100
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0857 - val_loss: 0.1997
# Epoch 13/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0744 - val_loss: 0.1938
# Epoch 14/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0727 - val_loss: 0.1888
# Epoch 15/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0786 - val_loss: 0.1836
# Epoch 16/100
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0680 - val_loss: 0.1779
# Epoch 17/100
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0670 - val_loss: 0.1732
# Epoch 18/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0725 - val_loss: 0.1683
# Epoch 19/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0629 - val_loss: 0.1629
# Epoch 20/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0619 - val_loss: 0.1584
# Epoch 21/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0672 - val_loss: 0.1538
# Epoch 22/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0584 - val_loss: 0.1487
# Epoch 23/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0571 - val_loss: 0.1445
# Epoch 24/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0618 - val_loss: 0.1402
# Epoch 25/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0540 - val_loss: 0.1355
# Epoch 26/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0528 - val_loss: 0.1315
# Epoch 27/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0572 - val_loss: 0.1276
# Epoch 28/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0501 - val_loss: 0.1234
# Epoch 29/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0490 - val_loss: 0.1199
# Epoch 30/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0530 - val_loss: 0.1165
# Epoch 31/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0466 - val_loss: 0.1129
# Epoch 32/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0460 - val_loss: 0.1100
# Epoch 33/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0498 - val_loss: 0.1072
# Epoch 34/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0439 - val_loss: 0.1044
# Epoch 35/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0430 - val_loss: 0.1022
# Epoch 36/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0464 - val_loss: 0.1000
# Epoch 37/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0413 - val_loss: 0.0979
# Epoch 38/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0404 - val_loss: 0.0962
# Epoch 39/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0442 - val_loss: 0.0945
# Epoch 40/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0393 - val_loss: 0.0928
# Epoch 41/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0383 - val_loss: 0.0915
# Epoch 42/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0418 - val_loss: 0.0902
# Epoch 43/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0370 - val_loss: 0.0888
# Epoch 44/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0369 - val_loss: 0.0877
# Epoch 45/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0400 - val_loss: 0.0866
# Epoch 46/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0355 - val_loss: 0.0855
# Epoch 47/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0351 - val_loss: 0.0846
# Epoch 48/100
# 100/100 [==============================] - 3s 32ms/step - loss: 0.0380 - val_loss: 0.0836
# Epoch 49/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0341 - val_loss: 0.0826
# Epoch 50/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0336 - val_loss: 0.0818
# Epoch 51/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0371 - val_loss: 0.0808
# Epoch 52/100
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0328 - val_loss: 0.0799
# Epoch 53/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0325 - val_loss: 0.0792
# Epoch 54/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0357 - val_loss: 0.0784
# Epoch 55/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0315 - val_loss: 0.0776
# Epoch 56/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0315 - val_loss: 0.0769
# Epoch 57/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0346 - val_loss: 0.0762
# Epoch 58/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0308 - val_loss: 0.0754
# Epoch 59/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0303 - val_loss: 0.0748
# Epoch 60/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0335 - val_loss: 0.0742
# Epoch 61/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0298 - val_loss: 0.0735
# Epoch 62/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0294 - val_loss: 0.0729
# Epoch 63/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0326 - val_loss: 0.0722
# Epoch 64/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0291 - val_loss: 0.0716
# Epoch 65/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0286 - val_loss: 0.0710
# Epoch 66/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0315 - val_loss: 0.0705
# Epoch 67/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0282 - val_loss: 0.0699
# Epoch 68/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0278 - val_loss: 0.0693
# Epoch 69/100
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0309 - val_loss: 0.0688
# Epoch 70/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0273 - val_loss: 0.0683
# Epoch 71/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0273 - val_loss: 0.0678
# Epoch 72/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0300 - val_loss: 0.0672
# Epoch 73/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0268 - val_loss: 0.0667
# Epoch 74/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0268 - val_loss: 0.0663
# Epoch 75/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0297 - val_loss: 0.0658
# Epoch 76/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0261 - val_loss: 0.0653
# Epoch 77/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0262 - val_loss: 0.0649
# Epoch 78/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0288 - val_loss: 0.0644
# Epoch 79/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0255 - val_loss: 0.0639
# Epoch 80/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0255 - val_loss: 0.0635
# Epoch 81/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0283 - val_loss: 0.0630
# Epoch 82/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0250 - val_loss: 0.0626
# Epoch 83/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0251 - val_loss: 0.0622
# Epoch 84/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0281 - val_loss: 0.0617
# Epoch 85/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0245 - val_loss: 0.0613
# Epoch 86/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0248 - val_loss: 0.0610
# Epoch 87/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0272 - val_loss: 0.0606
# Epoch 88/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0243 - val_loss: 0.0602
# Epoch 89/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0243 - val_loss: 0.0598
# Epoch 90/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0272 - val_loss: 0.0595
# Epoch 91/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0243 - val_loss: 0.0591
# Epoch 92/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0237 - val_loss: 0.0588
# Epoch 93/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0266 - val_loss: 0.0584
# Epoch 94/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0237 - val_loss: 0.0580
# Epoch 95/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0234 - val_loss: 0.0578
# Epoch 96/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0261 - val_loss: 0.0574
# Epoch 97/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0231 - val_loss: 0.0571
# Epoch 98/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0232 - val_loss: 0.0568
# Epoch 99/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0259 - val_loss: 0.0565
# Epoch 100/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0228 - val_loss: 0.0562

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']].tail(10))
data_val = X_scaler.fit_transform(df[['H-L',	'0-C','SMA_7','rsi_7','EMA_7']].tail(10))
# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=lstm_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 1s 872ms/step
# array([[3.3317485, 3.4427762, 3.3886914, 3.4329553, 2.9335032, 3.4288764,
#         3.079461 , 3.659523 , 3.4001956, 3.663663 ]], dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.3458395654523069
# MAE is : 0.5442503547058106
# RMSE is : 0.5880812575251033
# MAPE is : 19.305805417383144

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
