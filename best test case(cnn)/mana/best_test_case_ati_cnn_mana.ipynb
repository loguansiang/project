# %% [markdown]
# **(SAND) GRU model -‘Open’, ‘EMA_7’**

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
#slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(mana)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-11-09  0.014329  0.016111  0.013886  0.015130   0.015130     653800
# 2017-11-10  0.015162  0.015734  0.012645  0.012940   0.012940     296429
# 2017-11-11  0.013201  0.013616  0.011758  0.011979   0.011979     237865
# 2017-11-12  0.011975  0.011975  0.010125  0.010505   0.010505     242761
# 2017-11-13  0.010628  0.011660  0.010628  0.011330   0.011330     225836
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.153283  2.212506  2.113025  2.201286   2.201286  216991854
# 2022-04-14  2.200854  2.235230  2.100408  2.117604   2.117604  269798320
# 2022-04-15  2.117844  2.152222  2.107485  2.143937   2.143937  201367474
# 2022-04-16  2.143889  2.184819  2.117178  2.152566   2.152566  159910112
# 2022-04-17  2.154083  2.154435  2.125707  2.133954   2.133954  125790432
#
# [1621 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.8/dist-packages (0.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2017-11-15  0.011461  0.012014  0.011398  0.012002     283268   0.011419
# 2017-11-16  0.012013  0.012595  0.011742  0.011793     357512   0.012002
# 2017-11-17  0.011729  0.012085  0.011187  0.012028     268762   0.011793
# 2017-11-18  0.012021  0.013352  0.011435  0.013019     370149   0.012028
# 2017-11-19  0.012934  0.013975  0.012661  0.013099     379424   0.013019
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.153283  2.212506  2.113025  2.201286  216991854   2.153636
# 2022-04-14  2.200854  2.235230  2.100408  2.117604  269798320   2.201286
# 2022-04-15  2.117844  2.152222  2.107485  2.143937  201367474   2.117604
# 2022-04-16  2.143889  2.184819  2.117178  2.152566  159910112   2.143937
# 2022-04-17  2.154083  2.154435  2.125707  2.133954  125790432   2.152566
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2017-11-15  0.000616 -0.000541  0.012186  33.965216  0.011807
# 2017-11-16  0.000853  0.000220  0.011710  31.878810  0.011803
# 2017-11-17  0.000898 -0.000299  0.011579  36.958740  0.011864
# 2017-11-18  0.001917 -0.000998  0.011728  53.879565  0.012170
# 2017-11-19  0.001314 -0.000165  0.012099  55.016698  0.012413
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.099481 -0.048003  2.243642  37.935015  2.251587
# 2022-04-14  0.134822  0.083250  2.200956  33.194641  2.218091
# 2022-04-15  0.044737 -0.026093  2.183354  36.124984  2.199553
# 2022-04-16  0.067641 -0.008677  2.156682  37.178455  2.187806
# 2022-04-17  0.028728  0.020129  2.136927  35.696953  2.174343
#
# [1615 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['H-L',	'0-C','SMA_7','rsi_7','EMA_7']])
Y_data = Y_scaler.fit_transform(df[['Close']])

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[3.35052781e-05 7.58809413e-01 1.25256615e-04 2.76218916e-01
#   8.47734650e-07]
#  [1.03160988e-04 7.59075663e-01 2.68849219e-05 2.52505773e-01
#   0.00000000e+00]
#  [1.16386756e-04 7.58894081e-01 0.00000000e+00 3.10241946e-01
#   1.29376077e-05]
#  [4.15876917e-04 7.58649524e-01 3.06582443e-05 5.02556315e-01
#   7.81253218e-05]
#  [2.38651630e-04 7.58940964e-01 1.07126981e-04 5.15480445e-01
#   1.29788299e-04]
#  [1.34608924e-04 7.59014436e-01 1.57742563e-04 5.04003734e-01
#   1.64689330e-04]
#  [3.29468568e-04 7.58957757e-01 2.10303764e-04 5.35366863e-01
#   1.98826548e-04]
#  [7.49460168e-05 7.58875538e-01 2.56762796e-04 6.06691441e-01
#   2.44458927e-04]
#  [2.10436659e-04 7.58909126e-01 3.17106475e-04 6.51026278e-01
#   2.92466951e-04]
#  [1.76637475e-03 7.58253123e-01 4.31662184e-04 8.36482586e-01
#   4.39778126e-04]]
#
#  Target horizon
#
# [[0.00069503]
#  [0.00097085]
#  [0.00113747]
#  [0.00059169]
#  [0.00063614]
#  [0.00078173]
#  [0.00096536]
#  [0.00097633]
#  [0.00119051]
#  [0.00211655]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 16


train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 5)

# %%
#define model
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras import regularizers
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.0005

# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
l1_rate=regularizers.l1(0.01)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=16, kernel_size=1, activation='relu', input_shape=(x_train.shape[-2:]),activity_regularizer= l1_rate))
cnn_model.add(Conv1D(filters=32, kernel_size=1,activity_regularizer= l1_rate))
cnn_model.add(MaxPooling1D(pool_size=(1)))
cnn_model.add(Conv1D(filters=64, kernel_size=1,activity_regularizer= l1_rate))
cnn_model.add(Flatten())
cnn_model.add(Dense(128,activity_regularizer= l1_rate))
cnn_model.add(Dropout(0.2))
cnn_model.add(Dense(10,activity_regularizer= l1_rate))
# Compile the model with the optimizer
cnn_model.compile(optimizer=optimizer, loss='mse')
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 10, 16)            96
#
#  conv1d_4 (Conv1D)           (None, 10, 32)            544
#
#  max_pooling1d_1 (MaxPooling  (None, 10, 32)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 10, 64)            2112
#
#  flatten_1 (Flatten)         (None, 640)               0
#
#  dense_2 (Dense)             (None, 128)               82048
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 86,090
# Trainable params: 86,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = cnn_model.fit(train_data,epochs=100,batch_size=16,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 2s 7ms/step - loss: 0.8169 - val_loss: 0.7886
# Epoch 2/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.3409 - val_loss: 0.6714
# Epoch 3/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2342 - val_loss: 0.5785
# Epoch 4/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.1840 - val_loss: 0.5317
# Epoch 5/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1534 - val_loss: 0.4542
# Epoch 6/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.1192 - val_loss: 0.4216
# Epoch 7/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0983 - val_loss: 0.3903
# Epoch 8/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0806 - val_loss: 0.3645
# Epoch 9/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0732 - val_loss: 0.3282
# Epoch 10/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0543 - val_loss: 0.3110
# Epoch 11/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0430 - val_loss: 0.2936
# Epoch 12/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0338 - val_loss: 0.2839
# Epoch 13/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0287 - val_loss: 0.2643
# Epoch 14/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0171 - val_loss: 0.2488
# Epoch 15/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0069 - val_loss: 0.2432
# Epoch 16/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0049 - val_loss: 0.2374
# Epoch 17/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0065 - val_loss: 0.2292
# Epoch 18/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 0.2287
# Epoch 19/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.2267
# Epoch 20/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.2242
# Epoch 21/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.2240
# Epoch 22/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0061 - val_loss: 0.2171
# Epoch 23/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.2172
# Epoch 24/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0037 - val_loss: 0.2174
# Epoch 25/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.2166
# Epoch 26/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0062 - val_loss: 0.2150
# Epoch 27/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0039 - val_loss: 0.2144
# Epoch 28/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.2144
# Epoch 29/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.2130
# Epoch 30/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0060 - val_loss: 0.2087
# Epoch 31/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.2120
# Epoch 32/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.2115
# Epoch 33/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0037 - val_loss: 0.2106
# Epoch 34/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0057 - val_loss: 0.2046
# Epoch 35/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0046 - val_loss: 0.2100
# Epoch 36/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.2133
# Epoch 37/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0038 - val_loss: 0.2140
# Epoch 38/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.2147
# Epoch 39/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0064 - val_loss: 0.2153
# Epoch 40/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0040 - val_loss: 0.2178
# Epoch 41/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0039 - val_loss: 0.2187
# Epoch 42/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.2202
# Epoch 43/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.2204
# Epoch 44/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.2213
# Epoch 45/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.2164
# Epoch 46/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.2164
# Epoch 47/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.2047
# Epoch 48/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.2172
# Epoch 49/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.2186
# Epoch 50/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.2214
# Epoch 51/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.2218
# Epoch 52/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0052 - val_loss: 0.2398
# Epoch 53/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0042 - val_loss: 0.2484
# Epoch 54/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.2461
# Epoch 55/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.2419
# Epoch 56/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0065 - val_loss: 0.2434
# Epoch 57/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.2467
# Epoch 58/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.2423
# Epoch 59/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0038 - val_loss: 0.2403
# Epoch 60/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.2397
# Epoch 61/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.2365
# Epoch 62/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.2331
# Epoch 63/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0039 - val_loss: 0.2354
# Epoch 64/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0063 - val_loss: 0.2125
# Epoch 65/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0044 - val_loss: 0.2204
# Epoch 66/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.2182
# Epoch 67/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.2150
# Epoch 68/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0047 - val_loss: 0.2158
# Epoch 69/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0059 - val_loss: 0.2149
# Epoch 70/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0041 - val_loss: 0.2169
# Epoch 71/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0038 - val_loss: 0.2079
# Epoch 72/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.2117
# Epoch 73/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.2083
# Epoch 74/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.2032
# Epoch 75/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.2084
# Epoch 76/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.2131
# Epoch 77/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0063 - val_loss: 0.2111
# Epoch 78/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0044 - val_loss: 0.2171
# Epoch 79/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.2505
# Epoch 80/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.2513
# Epoch 81/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.2523
# Epoch 82/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0045 - val_loss: 0.2854
# Epoch 83/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.2522
# Epoch 84/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0038 - val_loss: 0.2448
# Epoch 85/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.2351
# Epoch 86/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0062 - val_loss: 0.2339
# Epoch 87/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.2257
# Epoch 88/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.2307
# Epoch 89/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.2300
# Epoch 90/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0066 - val_loss: 0.2370
# Epoch 91/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0043 - val_loss: 0.2348
# Epoch 92/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0041 - val_loss: 0.2683
# Epoch 93/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0040 - val_loss: 0.2610
# Epoch 94/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.2716
# Epoch 95/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0042 - val_loss: 0.2653
# Epoch 96/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.2522
# Epoch 97/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.2530
# Epoch 98/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0061 - val_loss: 0.2247
# Epoch 99/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.2336
# Epoch 100/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0039 - val_loss: 0.2214

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['open']


data_val = X_scaler.fit_transform(df[['H-L','0-C','SMA_7','rsi_7','EMA_7']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=cnn_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 0s 135ms/step
# array([[0.67860955, 0.5590322 , 0.7571227 , 1.0467318 , 1.1676377 ,
#         0.77398115, 0.9006391 , 0.7790964 , 0.63515526, 0.79202896]],
#       dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 1.9462387245158133
# MAE is : 1.3747112097904206
# RMSE is : 1.395076601665949
# MAPE is : 62.70556828014375

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
