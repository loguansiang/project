# %% [markdown]
# **(SAND) GRU model -‘Open’, ‘EMA_7’**

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
# mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(slp)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2020-07-08  0.199600  0.200201  0.109705  0.110012   0.110012       8412
# 2020-07-09  0.110270  0.149273  0.062864  0.091263   0.091263       5864
# 2020-07-10  0.091247  0.104638  0.045408  0.055206   0.055206        302
# 2020-07-11  0.055206  0.089824  0.023832  0.033257   0.033257        380
# 2020-07-12  0.033253  0.033525  0.018149  0.018416   0.018416         42
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  0.016956  0.017662  0.016659  0.017561   0.017561  195753852
# 2022-04-14  0.017563  0.018326  0.016753  0.017127   0.017127  214228125
# 2022-04-15  0.017128  0.017279  0.016853  0.017239   0.017239  107932100
# 2022-04-16  0.017242  0.017618  0.016952  0.017152   0.017152  128101400
# 2022-04-17  0.017156  0.017343  0.017092  0.017194   0.017194  110862176
#
# [649 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29106 sha256=93f31b655ac0c0c24eceb7547f905afd0ea15450bff98380026b94e0b4604687
#   Stored in directory: /root/.cache/pip/wheels/1b/81/50/db21d9643326c61dd6fee1dc2562d8351ee7753164c24ead38
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2020-07-14  0.012000  0.076397  0.011938  0.034327        419   0.011982
# 2020-07-15  0.034318  0.034480  0.010670  0.010735         79   0.034327
# 2020-07-16  0.010729  0.010755  0.009543  0.009627         35   0.010735
# 2020-07-17  0.009628  0.009658  0.009562  0.009590         35   0.009627
# 2020-07-18  0.009594  0.011825  0.009574  0.011774         42   0.009590
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  0.016956  0.017662  0.016659  0.017561  195753852   0.016955
# 2022-04-14  0.017563  0.018326  0.016753  0.017127  214228125   0.017561
# 2022-04-15  0.017128  0.017279  0.016853  0.017239  107932100   0.017127
# 2022-04-16  0.017242  0.017618  0.016952  0.017152  128101400   0.017239
# 2022-04-17  0.017156  0.017343  0.017092  0.017194  110862176   0.017152
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2020-07-14  0.064459 -0.022327  0.050638  27.681177  0.036470
# 2020-07-15  0.023810  0.023583  0.036455  20.642657  0.029320
# 2020-07-16  0.001212  0.001102  0.024793  20.359012  0.023997
# 2020-07-17  0.000096  0.000038  0.018276  20.348119  0.020181
# 2020-07-18  0.002251 -0.002180  0.015207  23.178636  0.017986
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.001003 -0.000605  0.018427  37.914164  0.018445
# 2022-04-14  0.001573  0.000436  0.017850  35.801746  0.018116
# 2022-04-15  0.000426 -0.000111  0.017545  36.860883  0.017897
# 2022-04-16  0.000666  0.000090  0.017231  36.317886  0.017710
# 2022-04-17  0.000251 -0.000038  0.017078  36.841893  0.017581
#
# [643 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['H-L',	'0-C','SMA_7','rsi_7','EMA_7']])
Y_data = Y_scaler.fit_transform(df[['Close']])

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[2.42133656e-01 5.29265806e-01 1.40412057e-01 2.33923431e-01
#   9.03049320e-02]
#  [8.92120866e-02 7.22672048e-01 9.13536969e-02 1.56577205e-01
#   6.56498498e-02]
#  [4.19839287e-03 6.27965759e-01 5.10127487e-02 1.53460232e-01
#   4.72932982e-02]
#  [0.00000000e+00 6.23483419e-01 2.84713125e-02 1.53340530e-01
#   3.41310704e-02]
#  [8.10711169e-03 6.14139593e-01 1.78553515e-02 1.84445051e-01
#   2.65638944e-02]
#  [1.72675836e-03 6.21495012e-01 1.47871347e-02 1.91327395e-01
#   2.14184242e-02]
#  [5.49252114e-04 6.23757246e-01 1.48459393e-02 1.90719714e-01
#   1.75387555e-02]
#  [1.66280435e-03 6.21414970e-01 4.07876655e-03 1.99978369e-01
#   1.50536440e-02]
#  [3.61904475e-03 6.19590860e-01 5.40804714e-03 2.21108089e-01
#   1.39845088e-02]
#  [2.79516658e-03 6.20660892e-01 7.59715979e-03 2.37869368e-01
#   1.37393515e-02]]
#
#  Target horizon
#
# [[0.0345849 ]
#  [0.035732  ]
#  [0.04800906]
#  [0.04678023]
#  [0.01231652]
#  [0.01026189]
#  [0.0107692 ]
#  [0.01726849]
#  [0.02293917]
#  [0.02313082]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 16


train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 5)

# %%
#define model
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow as tf
from tensorflow.keras import layers
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras import regularizers
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.0005

# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
l1_rate=regularizers.l1(0.01)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=16, kernel_size=1, activation='relu', input_shape=(x_train.shape[-2:]),activity_regularizer= l1_rate))
cnn_model.add(Conv1D(filters=32, kernel_size=1,activity_regularizer= l1_rate))
cnn_model.add(MaxPooling1D(pool_size=(1)))
cnn_model.add(Conv1D(filters=64, kernel_size=1,activity_regularizer= l1_rate))
cnn_model.add(Flatten())
cnn_model.add(Dense(128,activity_regularizer= l1_rate))
cnn_model.add(Dropout(0.2))
cnn_model.add(Dense(10,activity_regularizer= l1_rate))
# Compile the model with the optimizer
cnn_model.compile(optimizer=optimizer, loss='mse')
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 16)            96
#
#  conv1d_1 (Conv1D)           (None, 10, 32)            544
#
#  max_pooling1d (MaxPooling1D  (None, 10, 32)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 10, 64)            2112
#
#  flatten (Flatten)           (None, 640)               0
#
#  dense (Dense)               (None, 128)               82048
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 86,090
# Trainable params: 86,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = cnn_model.fit(train_data,epochs=100,batch_size=16,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 4s 14ms/step - loss: 0.7976 - val_loss: 0.4508
# Epoch 2/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.4154 - val_loss: 0.3038
# Epoch 3/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2971 - val_loss: 0.2257
# Epoch 4/100
# 100/100 [==============================] - 2s 19ms/step - loss: 0.2385 - val_loss: 0.1773
# Epoch 5/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.2054 - val_loss: 0.1489
# Epoch 6/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1810 - val_loss: 0.1449
# Epoch 7/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1605 - val_loss: 0.2050
# Epoch 8/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.1567 - val_loss: 0.1455
# Epoch 9/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.1378 - val_loss: 0.1079
# Epoch 10/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1255 - val_loss: 0.0904
# Epoch 11/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1100 - val_loss: 0.0736
# Epoch 12/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1015 - val_loss: 0.0609
# Epoch 13/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0958 - val_loss: 0.0520
# Epoch 14/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0932 - val_loss: 0.0671
# Epoch 15/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0817 - val_loss: 0.0939
# Epoch 16/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0812 - val_loss: 0.0738
# Epoch 17/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0778 - val_loss: 0.0492
# Epoch 18/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0768 - val_loss: 0.0417
# Epoch 19/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0756 - val_loss: 0.0390
# Epoch 20/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0765 - val_loss: 0.0387
# Epoch 21/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0807 - val_loss: 0.0406
# Epoch 22/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0836 - val_loss: 0.0677
# Epoch 23/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0775 - val_loss: 0.0895
# Epoch 24/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0759 - val_loss: 0.0748
# Epoch 25/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0754 - val_loss: 0.0461
# Epoch 26/100
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0746 - val_loss: 0.0427
# Epoch 27/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0750 - val_loss: 0.0404
# Epoch 28/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0738 - val_loss: 0.0389
# Epoch 29/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0783 - val_loss: 0.0528
# Epoch 30/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0806 - val_loss: 0.1023
# Epoch 31/100
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0761 - val_loss: 0.1144
# Epoch 32/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0758 - val_loss: 0.0714
# Epoch 33/100
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0742 - val_loss: 0.0437
# Epoch 34/100
# 100/100 [==============================] - 1s 10ms/step - loss: 0.0733 - val_loss: 0.0421
# Epoch 35/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0730 - val_loss: 0.0417
# Epoch 36/100
# 100/100 [==============================] - 1s 7ms/step - loss: 0.0727 - val_loss: 0.0392
# Epoch 37/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0770 - val_loss: 0.0489
# Epoch 38/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0781 - val_loss: 0.0961
# Epoch 39/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0737 - val_loss: 0.0864
# Epoch 40/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0723 - val_loss: 0.0733
# Epoch 41/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0722 - val_loss: 0.0431
# Epoch 42/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0704 - val_loss: 0.0391
# Epoch 43/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0697 - val_loss: 0.0398
# Epoch 44/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0705 - val_loss: 0.0390
# Epoch 45/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0739 - val_loss: 0.0503
# Epoch 46/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0765 - val_loss: 0.0814
# Epoch 47/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0718 - val_loss: 0.0936
# Epoch 48/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0702 - val_loss: 0.0618
# Epoch 49/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0690 - val_loss: 0.0488
# Epoch 50/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0684 - val_loss: 0.0389
# Epoch 51/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0687 - val_loss: 0.0356
# Epoch 52/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0678 - val_loss: 0.0355
# Epoch 53/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0724 - val_loss: 0.0387
# Epoch 54/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0742 - val_loss: 0.0814
# Epoch 55/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0691 - val_loss: 0.1052
# Epoch 56/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0687 - val_loss: 0.0661
# Epoch 57/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0676 - val_loss: 0.0369
# Epoch 58/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0679 - val_loss: 0.0383
# Epoch 59/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0674 - val_loss: 0.0391
# Epoch 60/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0670 - val_loss: 0.0335
# Epoch 61/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0702 - val_loss: 0.0395
# Epoch 62/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0712 - val_loss: 0.0800
# Epoch 63/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0664 - val_loss: 0.0867
# Epoch 64/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0666 - val_loss: 0.0607
# Epoch 65/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0659 - val_loss: 0.0372
# Epoch 66/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0653 - val_loss: 0.0385
# Epoch 67/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0652 - val_loss: 0.0339
# Epoch 68/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0652 - val_loss: 0.0333
# Epoch 69/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0697 - val_loss: 0.0444
# Epoch 70/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0709 - val_loss: 0.0775
# Epoch 71/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0665 - val_loss: 0.0896
# Epoch 72/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0657 - val_loss: 0.0550
# Epoch 73/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0640 - val_loss: 0.0342
# Epoch 74/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0643 - val_loss: 0.0354
# Epoch 75/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0638 - val_loss: 0.0334
# Epoch 76/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0641 - val_loss: 0.0291
# Epoch 77/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0681 - val_loss: 0.0368
# Epoch 78/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0701 - val_loss: 0.0629
# Epoch 79/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0642 - val_loss: 0.0953
# Epoch 80/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0648 - val_loss: 0.0577
# Epoch 81/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0640 - val_loss: 0.0353
# Epoch 82/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0642 - val_loss: 0.0356
# Epoch 83/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0644 - val_loss: 0.0354
# Epoch 84/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0644 - val_loss: 0.0312
# Epoch 85/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0678 - val_loss: 0.0435
# Epoch 86/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0701 - val_loss: 0.0666
# Epoch 87/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0655 - val_loss: 0.0803
# Epoch 88/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0642 - val_loss: 0.0589
# Epoch 89/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0633 - val_loss: 0.0344
# Epoch 90/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0631 - val_loss: 0.0326
# Epoch 91/100
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0630 - val_loss: 0.0330
# Epoch 92/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0633 - val_loss: 0.0304
# Epoch 93/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0669 - val_loss: 0.0400
# Epoch 94/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0688 - val_loss: 0.0789
# Epoch 95/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0647 - val_loss: 0.0818
# Epoch 96/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0639 - val_loss: 0.0536
# Epoch 97/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0628 - val_loss: 0.0393
# Epoch 98/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0622 - val_loss: 0.0324
# Epoch 99/100
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0622 - val_loss: 0.0316
# Epoch 100/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0628 - val_loss: 0.0291

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['open']


data_val = X_scaler.fit_transform(df[['H-L','0-C','SMA_7','rsi_7','EMA_7']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=cnn_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 0s 183ms/step
# array([[0.05430416, 0.05083198, 0.05801229, 0.06269298, 0.05371814,
#         0.05920843, 0.06211904, 0.05628296, 0.0605719 , 0.06362695]],
#       dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.0016618011388869762
# MAE is : 0.040483682632970815
# RMSE is : 0.040765195190100294
# MAPE is : 231.12128652204112

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
