# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras import optimizers
import matplotlib.pyplot as plt
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout,Activation
from keras import optimizers
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
#sand = 'https://raw.githubusercontent.com/loguansiang/fyp/main/SAND%20fyp.csv'
#slp= 'https://raw.githubusercontent.com/loguansiang/fyp/main/SLP%20fyp.csv'
mana = 'https://raw.githubusercontent.com/loguansiang/fyp/main/MANA%20fyp.csv'

df = pd.read_csv(mana)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-11-09  0.014329  0.016111  0.013886  0.015130   0.015130     653800
# 2017-11-10  0.015162  0.015734  0.012645  0.012940   0.012940     296429
# 2017-11-11  0.013201  0.013616  0.011758  0.011979   0.011979     237865
# 2017-11-12  0.011975  0.011975  0.010125  0.010505   0.010505     242761
# 2017-11-13  0.010628  0.011660  0.010628  0.011330   0.011330     225836
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.153283  2.212506  2.113025  2.201286   2.201286  216991854
# 2022-04-14  2.200854  2.235230  2.100408  2.117604   2.117604  269798320
# 2022-04-15  2.117844  2.152222  2.107485  2.143937   2.143937  201367474
# 2022-04-16  2.143889  2.184819  2.117178  2.152566   2.152566  159910112
# 2022-04-17  2.154083  2.154435  2.125707  2.133954   2.133954  125790432
#
# [1621 rows x 6 columns]

# %%
pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ta in /usr/local/lib/python3.8/dist-packages (0.10.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)

# %%
import pandas as pd
import ta
from ta import add_all_ta_features
from ta.utils import dropna

# %%
df['Pre_Close'] = df['Close'].shift(+1)
df[('H-L')] = df['High'] - df['Low']
df[('0-C')]= df['Open'] - df['Close']
df['SMA_7'] = df.Close.rolling(7, min_periods=1).mean()
df['rsi_7']=ta.momentum.rsi(df.Close,window=7)
#df['MACD'] = ta.trend.macd_diff(df.Close)
df['EMA_7']= df['Close'].ewm(span=7).mean()
df = df.drop(columns=['Adj Close'])
df.dropna(inplace= True)
df
# Out:
#                 Open      High       Low     Close     Volume  Pre_Close  \
# Date
# 2017-11-15  0.011461  0.012014  0.011398  0.012002     283268   0.011419
# 2017-11-16  0.012013  0.012595  0.011742  0.011793     357512   0.012002
# 2017-11-17  0.011729  0.012085  0.011187  0.012028     268762   0.011793
# 2017-11-18  0.012021  0.013352  0.011435  0.013019     370149   0.012028
# 2017-11-19  0.012934  0.013975  0.012661  0.013099     379424   0.013019
# ...              ...       ...       ...       ...        ...        ...
# 2022-04-13  2.153283  2.212506  2.113025  2.201286  216991854   2.153636
# 2022-04-14  2.200854  2.235230  2.100408  2.117604  269798320   2.201286
# 2022-04-15  2.117844  2.152222  2.107485  2.143937  201367474   2.117604
# 2022-04-16  2.143889  2.184819  2.117178  2.152566  159910112   2.143937
# 2022-04-17  2.154083  2.154435  2.125707  2.133954  125790432   2.152566
#
#                  H-L       0-C     SMA_7      rsi_7     EMA_7
# Date
# 2017-11-15  0.000616 -0.000541  0.012186  33.965216  0.011807
# 2017-11-16  0.000853  0.000220  0.011710  31.878810  0.011803
# 2017-11-17  0.000898 -0.000299  0.011579  36.958740  0.011864
# 2017-11-18  0.001917 -0.000998  0.011728  53.879565  0.012170
# 2017-11-19  0.001314 -0.000165  0.012099  55.016698  0.012413
# ...              ...       ...       ...        ...       ...
# 2022-04-13  0.099481 -0.048003  2.243642  37.935015  2.251587
# 2022-04-14  0.134822  0.083250  2.200956  33.194641  2.218091
# 2022-04-15  0.044737 -0.026093  2.183354  36.124984  2.199553
# 2022-04-16  0.067641 -0.008677  2.156682  37.178455  2.187806
# 2022-04-17  0.028728  0.020129  2.136927  35.696953  2.174343
#
# [1615 rows x 11 columns]

# %%
def data_prep(dataset, target, data_start, data_end, look_back, horizon):
    dataX,dataY = [],[]
    data_start = data_start + look_back
    if data_end is None:
        data_end = len(dataset) - horizon

    for i in range(data_start, data_end):
        a = range(i-look_back, i)
        dataX.append(dataset[a])

        b = range(i+1, i+1+horizon)
        dataY.append(target[b])
    return np.array(dataX), np.array(dataY)

# %%
X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()
# X_data = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']])//experiment4
X_data = X_scaler.fit_transform(df[['Pre_Close']])
Y_data = Y_scaler.fit_transform(df[['Close']])

##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# %%
##TRAIN_SPLIT = int(len(df) * 0.8)
look_back = 10
horizon = 10
train_split = int(len(df) * 0.8)
x_train, y_train = data_prep(X_data, Y_data, 0, train_split, look_back, horizon)
x_vali, y_vali = data_prep(X_data, Y_data, train_split, None, look_back, horizon)

# %%
x_train
# Out:
# array([[[0.00000000e+00],
#         [1.06624977e-04],
#         [6.84009289e-05],
#         ...,
#         [3.26093199e-04],
#         [3.94859908e-04],
#         [4.42777136e-04]],
#
#        [[1.06624977e-04],
#         [6.84009289e-05],
#         [1.11380122e-04],
#         ...,
#         [3.94859908e-04],
#         [4.42777136e-04],
#         [8.22091379e-04]],
#
#        [[6.84009289e-05],
#         [1.11380122e-04],
#         [2.92624295e-04],
#         ...,
#         [4.42777136e-04],
#         [8.22091379e-04],
#         [7.51861548e-04]],
#
#        ...,
#
#        [[2.13648838e-01],
#         [1.92112605e-01],
#         [2.03950721e-01],
#         ...,
#         [1.12135276e-01],
#         [1.39974637e-01],
#         [1.41657958e-01]],
#
#        [[1.92112605e-01],
#         [2.03950721e-01],
#         [1.40624629e-01],
#         ...,
#         [1.39974637e-01],
#         [1.41657958e-01],
#         [1.82131373e-01]],
#
#        [[2.03950721e-01],
#         [1.40624629e-01],
#         [1.72940227e-01],
#         ...,
#         [1.41657958e-01],
#         [1.82131373e-01],
#         [1.61682787e-01]]])

# %%
print ('Multiple window of past history\n')
print(x_train[0])
print ('\n Target horizon\n')
print (y_train[0])
# Out:
# Multiple window of past history
#
# [[0.00000000e+00]
#  [1.06624977e-04]
#  [6.84009289e-05]
#  [1.11380122e-04]
#  [2.92624295e-04]
#  [3.07255510e-04]
#  [2.97745220e-04]
#  [3.26093199e-04]
#  [3.94859908e-04]
#  [4.42777136e-04]]
#
#  Target horizon
#
# [[0.00069503]
#  [0.00097085]
#  [0.00113747]
#  [0.00059169]
#  [0.00063614]
#  [0.00078173]
#  [0.00096536]
#  [0.00097633]
#  [0.00119051]
#  [0.00211655]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px # to plot the time series plot
from sklearn import metrics # for the evalution
from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import tensorflow as tf

# %%
batch_size = 64
buffer_size = 18

train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_data = train_data.batch(batch_size).repeat()

val_data = tf.data.Dataset.from_tensor_slices((x_vali, y_vali))
val_data = val_data.batch(batch_size).repeat()

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
# from keras.layers.merge import concatenate
import tensorflow as tf

# %%
x_train.shape[-2:]
# Out:
# (10, 1)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from keras.optimizers import Adam
# Set the learning rate
#0.0001,0.001,0.01,0.1,1
learning_rate = 0.00001

# Create the optimizer with the desired learning rate
optimizer = Adam(learning_rate=learning_rate)
# Set random seed for as reproducible results as possible
tf.random.set_seed(7)

lstm_model = Sequential()
lstm_model.add(GRU(64,return_sequences=True,input_shape=(x_train.shape[-2:])))
lstm_model.add(Dense(20,activation='linear'))
lstm_model.add(GRU(32))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(units=horizon,activation='linear'))
lstm_model.add(Activation('linear'))
lstm_model.compile(optimizer=optimizer, loss='mse')
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 10, 64)            12864
#
#  dense_2 (Dense)             (None, 10, 20)            1300
#
#  gru_3 (GRU)                 (None, 32)                5184
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 10)                330
#
#  activation_1 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 19,678
# Trainable params: 19,678
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = lstm_model.fit(train_data,epochs=100,steps_per_epoch=100,batch_size=64,validation_data=val_data,validation_steps=50,verbose=1)#callback
##history = cnn_model.fit(train_data,epochs=50,steps_per_epoch=100,validation_data=val_data,validation_steps=50,verbose=1)
# Out:
# Epoch 1/100
# 100/100 [==============================] - 6s 24ms/step - loss: 0.0023 - val_loss: 0.1724
# Epoch 2/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0028 - val_loss: 0.1687
# Epoch 3/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0027 - val_loss: 0.1653
# Epoch 4/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0026 - val_loss: 0.1623
# Epoch 5/100
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0020 - val_loss: 0.1594
# Epoch 6/100
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0024 - val_loss: 0.1565
# Epoch 7/100
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0024 - val_loss: 0.1538
# Epoch 8/100
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0024 - val_loss: 0.1514
# Epoch 9/100
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0019 - val_loss: 0.1491
# Epoch 10/100
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0023 - val_loss: 0.1466
# Epoch 11/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0022 - val_loss: 0.1443
# Epoch 12/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0022 - val_loss: 0.1421
# Epoch 13/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0018 - val_loss: 0.1401
# Epoch 14/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0021 - val_loss: 0.1378
# Epoch 15/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0021 - val_loss: 0.1355
# Epoch 16/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0021 - val_loss: 0.1335
# Epoch 17/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0021 - val_loss: 0.1315
# Epoch 18/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0017 - val_loss: 0.1294
# Epoch 19/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0020 - val_loss: 0.1271
# Epoch 20/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0020 - val_loss: 0.1249
# Epoch 21/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0020 - val_loss: 0.1228
# Epoch 22/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0016 - val_loss: 0.1206
# Epoch 23/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0019 - val_loss: 0.1182
# Epoch 24/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0019 - val_loss: 0.1159
# Epoch 25/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0019 - val_loss: 0.1136
# Epoch 26/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0015 - val_loss: 0.1113
# Epoch 27/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0018 - val_loss: 0.1087
# Epoch 28/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0017 - val_loss: 0.1060
# Epoch 29/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0017 - val_loss: 0.1035
# Epoch 30/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0014 - val_loss: 0.1010
# Epoch 31/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0016 - val_loss: 0.0980
# Epoch 32/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0016 - val_loss: 0.0950
# Epoch 33/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0016 - val_loss: 0.0921
# Epoch 34/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0013 - val_loss: 0.0893
# Epoch 35/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0014 - val_loss: 0.0862
# Epoch 36/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0015 - val_loss: 0.0830
# Epoch 37/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0014 - val_loss: 0.0800
# Epoch 38/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0014 - val_loss: 0.0770
# Epoch 39/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0011 - val_loss: 0.0737
# Epoch 40/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0013 - val_loss: 0.0703
# Epoch 41/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0012 - val_loss: 0.0670
# Epoch 42/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0012 - val_loss: 0.0640
# Epoch 43/100
# 100/100 [==============================] - 2s 16ms/step - loss: 9.5656e-04 - val_loss: 0.0610
# Epoch 44/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0011 - val_loss: 0.0578
# Epoch 45/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0011 - val_loss: 0.0549
# Epoch 46/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0011 - val_loss: 0.0520
# Epoch 47/100
# 100/100 [==============================] - 2s 16ms/step - loss: 8.1357e-04 - val_loss: 0.0493
# Epoch 48/100
# 100/100 [==============================] - 2s 16ms/step - loss: 9.5908e-04 - val_loss: 0.0465
# Epoch 49/100
# 100/100 [==============================] - 2s 16ms/step - loss: 9.6369e-04 - val_loss: 0.0439
# Epoch 50/100
# 100/100 [==============================] - 2s 16ms/step - loss: 9.1173e-04 - val_loss: 0.0417
# Epoch 51/100
# 100/100 [==============================] - 2s 16ms/step - loss: 7.0397e-04 - val_loss: 0.0395
# Epoch 52/100
# 100/100 [==============================] - 2s 16ms/step - loss: 8.5282e-04 - val_loss: 0.0373
# Epoch 53/100
# 100/100 [==============================] - 2s 16ms/step - loss: 8.2020e-04 - val_loss: 0.0352
# Epoch 54/100
# 100/100 [==============================] - 2s 16ms/step - loss: 8.0439e-04 - val_loss: 0.0334
# Epoch 55/100
# 100/100 [==============================] - 2s 22ms/step - loss: 6.8080e-04 - val_loss: 0.0319
# Epoch 56/100
# 100/100 [==============================] - 3s 30ms/step - loss: 7.3185e-04 - val_loss: 0.0303
# Epoch 57/100
# 100/100 [==============================] - 3s 25ms/step - loss: 7.5679e-04 - val_loss: 0.0289
# Epoch 58/100
# 100/100 [==============================] - 2s 21ms/step - loss: 7.2904e-04 - val_loss: 0.0276
# Epoch 59/100
# 100/100 [==============================] - 2s 24ms/step - loss: 7.0944e-04 - val_loss: 0.0264
# Epoch 60/100
# 100/100 [==============================] - 2s 21ms/step - loss: 5.6213e-04 - val_loss: 0.0251
# Epoch 61/100
# 100/100 [==============================] - 2s 16ms/step - loss: 7.0026e-04 - val_loss: 0.0239
# Epoch 62/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.5994e-04 - val_loss: 0.0232
# Epoch 63/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.6749e-04 - val_loss: 0.0222
# Epoch 64/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.4306e-04 - val_loss: 0.0213
# Epoch 65/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.4274e-04 - val_loss: 0.0206
# Epoch 66/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.2630e-04 - val_loss: 0.0199
# Epoch 67/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.4771e-04 - val_loss: 0.0194
# Epoch 68/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.9020e-04 - val_loss: 0.0190
# Epoch 69/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.0901e-04 - val_loss: 0.0184
# Epoch 70/100
# 100/100 [==============================] - 2s 17ms/step - loss: 6.1634e-04 - val_loss: 0.0180
# Epoch 71/100
# 100/100 [==============================] - 2s 16ms/step - loss: 6.0104e-04 - val_loss: 0.0178
# Epoch 72/100
# 100/100 [==============================] - 2s 17ms/step - loss: 4.6989e-04 - val_loss: 0.0177
# Epoch 73/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.6665e-04 - val_loss: 0.0173
# Epoch 74/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.7079e-04 - val_loss: 0.0170
# Epoch 75/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.9863e-04 - val_loss: 0.0166
# Epoch 76/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.8507e-04 - val_loss: 0.0162
# Epoch 77/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.3696e-04 - val_loss: 0.0160
# Epoch 78/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.6891e-04 - val_loss: 0.0155
# Epoch 79/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.5680e-04 - val_loss: 0.0152
# Epoch 80/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.4643e-04 - val_loss: 0.0151
# Epoch 81/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.5872e-04 - val_loss: 0.0147
# Epoch 82/100
# 100/100 [==============================] - 2s 17ms/step - loss: 5.6159e-04 - val_loss: 0.0145
# Epoch 83/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.3807e-04 - val_loss: 0.0145
# Epoch 84/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.2881e-04 - val_loss: 0.0146
# Epoch 85/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.3861e-04 - val_loss: 0.0146
# Epoch 86/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.1575e-04 - val_loss: 0.0140
# Epoch 87/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.3371e-04 - val_loss: 0.0139
# Epoch 88/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.1192e-04 - val_loss: 0.0141
# Epoch 89/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.0987e-04 - val_loss: 0.0138
# Epoch 90/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.1223e-04 - val_loss: 0.0137
# Epoch 91/100
# 100/100 [==============================] - 2s 17ms/step - loss: 5.0506e-04 - val_loss: 0.0135
# Epoch 92/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.0180e-04 - val_loss: 0.0134
# Epoch 93/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.0874e-04 - val_loss: 0.0133
# Epoch 94/100
# 100/100 [==============================] - 2s 17ms/step - loss: 5.0164e-04 - val_loss: 0.0130
# Epoch 95/100
# 100/100 [==============================] - 2s 17ms/step - loss: 5.0790e-04 - val_loss: 0.0131
# Epoch 96/100
# 100/100 [==============================] - 2s 16ms/step - loss: 5.0289e-04 - val_loss: 0.0131
# Epoch 97/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.3224e-04 - val_loss: 0.0134
# Epoch 98/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.6074e-04 - val_loss: 0.0132
# Epoch 99/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.8666e-04 - val_loss: 0.0134
# Epoch 100/100
# 100/100 [==============================] - 2s 16ms/step - loss: 4.7312e-04 - val_loss: 0.0134

# %%
plt.figure(figsize=(16,9))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Pre_Close', 'H-L', '0-C',
#        'SMA_7', 'rsi_7', 'EMA_7'],
#       dtype='object')

# %%
##['Open', 'High', 'Low','Volume']
##['H-L',	'0-C','SMA_7','rsi_7','EMA_7']

# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume','H-L',	'0-C','SMA_7','rsi_7','EMA_7']].tail(10))
data_val = X_scaler.fit_transform(df[['Pre_Close']].tail(10))
# data_val = X_scaler.fit_transform(df[['Open', 'High', 'Low','Volume']].tail(10))
val_rescaled = data_val.reshape(1, data_val.shape[0], data_val.shape[1])
pred=lstm_model.predict(val_rescaled)
pred_Inverse = Y_scaler.inverse_transform(pred)
pred_Inverse
# Out:
# 1/1 [==============================] - 1s 730ms/step
# array([[1.689068 , 1.768798 , 1.7716974, 1.7215935, 1.5807831, 1.7043699,
#         1.565812 , 1.5986279, 1.847784 , 1.7165943]], dtype=float32)

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')

# %%
validate = (df[['Close']].tail(10))
timeseries_evaluation_metrics_func(validate['Close'],pred_Inverse[0])
# Out:
# Evaluation metric results:-
# MSE is : 0.24656582140296462
# MAE is : 0.48720188166351325
# RMSE is : 0.4965539461155904
# MAPE is : 22.254086474571775

# %%
plt.figure(figsize=(16,9))
plt.plot( list(validate['Close']))
plt.plot( list(pred_Inverse[0]))
plt.title("Actual vs Predicted")
plt.ylabel("Close")
plt.legend(('Actual','predicted'))
plt.show()
